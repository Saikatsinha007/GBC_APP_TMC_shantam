# %%
# Import the required libraries & modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
gbc_patients = pd.read_excel("GBC.xlsx")

# %%
gbc_patients.head()
# Out:
#           MR_NO Comorbidities_final      Thyroidism Diabetes  HTN  \
# 0  MR/17/000051                 NaN              No       No  Yes
# 1  MR/17/000165                 NaN              No       No   No
# 2  MR/17/000504                 NaN  Hypothyroidism      Yes  Yes
# 3  MR/17/000600                 NaN              No       No  Yes
# 4  MR/17/000665                 NaN              No       No   No
#
#   Family_cancer_history ECOG_final Gall_stone_final       Pathology  \
# 0                    No          1              Yes  Adenocarcinoma
# 1                    No  Not known               No  Adenocarcinoma
# 2             Not known  Not known        Not known  Adenocarcinoma
# 3                    No          1               No  Adenocarcinoma
# 4                    No          1        Not known  Adenocarcinoma
#
#   Tumour_grade_final  ... ALT - SGPT ALK PHOS [ALP] GAMMA GT ALBUMIN  \
# 0            Grade 3  ...       28.0          147.0     21.0     4.7
# 1            Grade X  ...       27.0           83.0     76.0     3.4
# 2            Grade 3  ...        NaN            NaN      NaN     NaN
# 3            Grade X  ...       98.0          481.0     83.0     4.1
# 4            Grade X  ...       78.0          206.0    481.0     3.2
#
#   CREATININE_from_UnC_test UREA_from_UnC_test ESTIMATED AVERAGE GLUCOSE (eAG)  \
# 0                      NaN                NaN                           137.0
# 1                      NaN                NaN                             NaN
# 2                      NaN                NaN                             NaN
# 3                      NaN                NaN                           117.0
# 4                      NaN                NaN                             NaN
#
#   HbA1c CREATININE_from_CREATININE_test Diabetes_final
# 0   6.4                            0.64            Yes
# 1   NaN                             NaN             No
# 2   NaN                             NaN            Yes
# 3   5.7                            1.08            Yes
# 4   NaN                            0.60             No
#
# [5 rows x 50 columns]

# %%
gbc_patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 50 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   MR_NO                            698 non-null    object
#  1   Comorbidities_final              566 non-null    object
#  2   Thyroidism                       657 non-null    object
#  3   Diabetes                         659 non-null    object
#  4   HTN                              659 non-null    object
#  5   Family_cancer_history            657 non-null    object
#  6   ECOG_final                       660 non-null    object
#  7   Gall_stone_final                 657 non-null    object
#  8   Pathology                        698 non-null    object
#  9   Tumour_grade_final               646 non-null    object
#  10  Cancer_presentation_final        642 non-null    object
#  11  Tumour_stage_final               620 non-null    object
#  12  TNM_classification               618 non-null    object
#  13  Metastasis_final                 632 non-null    object
#  14  Site_metastasis                  533 non-null    object
#  15  Mets_site_final                  630 non-null    object
#  16  Cholecystectomy_TMC              489 non-null    object
#  17  Outside_cholecystectomy          657 non-null    object
#  18  Surgery_final                    660 non-null    object
#  19  Treatment_final                  642 non-null    object
#  20  Treatment_clean                  630 non-null    object
#  21  Treatment                        630 non-null    object
#  22  Status                           584 non-null    object
#  23  Date_event                       434 non-null    datetime64[ns]
#  24  Date_diagnosis                   653 non-null    datetime64[ns]
#  25  AGE                              698 non-null    int64
#  26  GENDER                           698 non-null    object
#  27  COUNTRY                          698 non-null    object
#  28  STATE_NAME                       698 non-null    object
#  29  CITY_NAME                        698 non-null    object
#  30  PINCODE                          615 non-null    float64
#  31  First_Visit_Date                 566 non-null    datetime64[ns]
#  32  HEIGHT                           566 non-null    float64
#  33  WEIGHT                           566 non-null    float64
#  34  BSA_DETAILS                      566 non-null    float64
#  35  BMI_DETAILS                      566 non-null    float64
#  36  BILIRUBIN CONJUGATED             425 non-null    float64
#  37  BILIRUBIN UNCONJUGATED           425 non-null    float64
#  38  BILIRUBIN TOTAL                  425 non-null    float64
#  39  AST - SGOT                       425 non-null    float64
#  40  ALT - SGPT                       424 non-null    float64
#  41  ALK PHOS [ALP]                   425 non-null    float64
#  42  GAMMA GT                         423 non-null    float64
#  43  ALBUMIN                          424 non-null    float64
#  44  CREATININE_from_UnC_test         21 non-null     float64
#  45  UREA_from_UnC_test               21 non-null     float64
#  46  ESTIMATED AVERAGE GLUCOSE (eAG)  80 non-null     float64
#  47  HbA1c                            80 non-null     float64
#  48  CREATININE_from_CREATININE_test  180 non-null    float64
#  49  Diabetes_final                   659 non-null    object
# dtypes: datetime64[ns](3), float64(18), int64(1), object(28)
# memory usage: 272.8+ KB

# %%
# Check the total missing values in each column.
print("Total NULL Values in each columns")
print("**************************************")
print(gbc_patients.isnull().sum())
# Out:
# Total NULL Values in each columns
# **************************************
# MR_NO                                0
# Comorbidities_final                132
# Thyroidism                          41
# Diabetes                            39
# HTN                                 39
# Family_cancer_history               41
# ECOG_final                          38
# Gall_stone_final                    41
# Pathology                            0
# Tumour_grade_final                  52
# Cancer_presentation_final           56
# Tumour_stage_final                  78
# TNM_classification                  80
# Metastasis_final                    66
# Site_metastasis                    165
# Mets_site_final                     68
# Cholecystectomy_TMC                209
# Outside_cholecystectomy             41
# Surgery_final                       38
# Treatment_final                     56
# Treatment_clean                     68
# Treatment                           68
# Status                             114
# Date_event                         264
# Date_diagnosis                      45
# AGE                                  0
# GENDER                               0
# COUNTRY                              0
# STATE_NAME                           0
# CITY_NAME                            0
# PINCODE                             83
# First_Visit_Date                   132
# HEIGHT                             132
# WEIGHT                             132
# BSA_DETAILS                        132
# BMI_DETAILS                        132
# BILIRUBIN CONJUGATED               273
# BILIRUBIN UNCONJUGATED             273
# BILIRUBIN TOTAL                    273
# AST - SGOT                         273
# ALT - SGPT                         274
# ALK PHOS [ALP]                     273
# GAMMA GT                           275
# ALBUMIN                            274
# CREATININE_from_UnC_test           677
# UREA_from_UnC_test                 677
# ESTIMATED AVERAGE GLUCOSE (eAG)    618
# HbA1c                              618
# CREATININE_from_CREATININE_test    518
# Diabetes_final                      39
# dtype: int64

# %% [markdown]
# **No. of patients with defined "Status"**

# %%
sns.distplot(gbc_patients["AGE"])
# Out:
# C:\Users\sriva\AppData\Local\Temp\ipykernel_45344\944376550.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(gbc_patients["AGE"])
# <Axes: xlabel='AGE', ylabel='Density'>

# %%
gbc_patients["AGE"].median()
# Out:
# 58.0

# %%
### MALE VS FEMALE RATIO

# %%
gbc_patients["GENDER"].value_counts()
# Out:
# FEMA    462
# MALE    236
# Name: GENDER, dtype: int64

# %%
gbc_patients["Status"].value_counts()
# Out:
# Dead         460
# Not Known     63
# Alive         34
# Live          26
# No             1
# Name: Status, dtype: int64

# %%
#count gives the no. of observations excluding the missing data
gbc_patients["Status"].count()
# Out:
# 584

# %%
gbc_patients.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 50 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   MR_NO                            698 non-null    object
#  1   Comorbidities_final              566 non-null    object
#  2   Thyroidism                       657 non-null    object
#  3   Diabetes                         659 non-null    object
#  4   HTN                              659 non-null    object
#  5   Family_cancer_history            657 non-null    object
#  6   ECOG_final                       660 non-null    object
#  7   Gall_stone_final                 657 non-null    object
#  8   Pathology                        698 non-null    object
#  9   Tumour_grade_final               646 non-null    object
#  10  Cancer_presentation_final        642 non-null    object
#  11  Tumour_stage_final               620 non-null    object
#  12  TNM_classification               618 non-null    object
#  13  Metastasis_final                 632 non-null    object
#  14  Site_metastasis                  533 non-null    object
#  15  Mets_site_final                  630 non-null    object
#  16  Cholecystectomy_TMC              489 non-null    object
#  17  Outside_cholecystectomy          657 non-null    object
#  18  Surgery_final                    660 non-null    object
#  19  Treatment_final                  642 non-null    object
#  20  Treatment_clean                  630 non-null    object
#  21  Treatment                        630 non-null    object
#  22  Status                           584 non-null    object
#  23  Date_event                       434 non-null    datetime64[ns]
#  24  Date_diagnosis                   653 non-null    datetime64[ns]
#  25  AGE                              698 non-null    int64
#  26  GENDER                           698 non-null    object
#  27  COUNTRY                          698 non-null    object
#  28  STATE_NAME                       698 non-null    object
#  29  CITY_NAME                        698 non-null    object
#  30  PINCODE                          615 non-null    float64
#  31  First_Visit_Date                 566 non-null    datetime64[ns]
#  32  HEIGHT                           566 non-null    float64
#  33  WEIGHT                           566 non-null    float64
#  34  BSA_DETAILS                      566 non-null    float64
#  35  BMI_DETAILS                      566 non-null    float64
#  36  BILIRUBIN CONJUGATED             425 non-null    float64
#  37  BILIRUBIN UNCONJUGATED           425 non-null    float64
#  38  BILIRUBIN TOTAL                  425 non-null    float64
#  39  AST - SGOT                       425 non-null    float64
#  40  ALT - SGPT                       424 non-null    float64
#  41  ALK PHOS [ALP]                   425 non-null    float64
#  42  GAMMA GT                         423 non-null    float64
#  43  ALBUMIN                          424 non-null    float64
#  44  CREATININE_from_UnC_test         21 non-null     float64
#  45  UREA_from_UnC_test               21 non-null     float64
#  46  ESTIMATED AVERAGE GLUCOSE (eAG)  80 non-null     float64
#  47  HbA1c                            80 non-null     float64
#  48  CREATININE_from_CREATININE_test  180 non-null    float64
#  49  Diabetes_final                   659 non-null    object
# dtypes: datetime64[ns](3), float64(18), int64(1), object(28)
# memory usage: 272.8+ KB

# %%
"ALBUMIN", "CREATININE_from_UnC_test", "UREA_from_UnC_test", "ESTIMATED AVERAGE GLUCOSE (eAG)", "HbA1c", "CREATININE_from_CREATININE_test"
# Out:
# ('ALBUMIN',
#  'CREATININE_from_UnC_test',
#  'UREA_from_UnC_test',
#  'ESTIMATED AVERAGE GLUCOSE (eAG)',
#  'HbA1c',
#  'CREATININE_from_CREATININE_test')

# %%
#gbc_patients["Comorbidities_final"].value_counts()

# %%
gbc_patients["Thyroidism"].value_counts()
# Out:
# No                493
# Not known         104
# Hypothyroidism     60
# Name: Thyroidism, dtype: int64

# %%
gbc_patients["Diabetes"].value_counts()
# Out:
# No           391
# Yes          165
# Not known    103
# Name: Diabetes, dtype: int64

# %%
#gbc_patients["Diabetes_final"].value_counts()

# %%
gbc_patients["HTN"].value_counts()
# Out:
# No           326
# Yes          237
# Not known     96
# Name: HTN, dtype: int64

# %%
gbc_patients["Family_cancer_history"].value_counts()
# Out:
# Not known    336
# No           260
# Yes           61
# Name: Family_cancer_history, dtype: int64

# %%
gbc_patients["ECOG_final"].value_counts()
# Out:
# 1            374
# 2            135
# Not known     53
# 3             49
# 0             29
# 4             20
# Name: ECOG_final, dtype: int64

# %%
gbc_patients["Gall_stone_final"].value_counts()
# Out:
# Yes          266
# No           194
# Not known    189
# Polyp          8
# Name: Gall_stone_final, dtype: int64

# %%
gbc_patients["Pathology"].value_counts() #merge categories
# Out:
# Adenocarcinoma                  575
# Carcinoma                        58
# Adenosquamous carcinoma          23
# Others                           14
# Neuroendocrine carcinoma         12
# Mucinous adenocarcinoma           8
# ICPN with invasive carcinoma      5
# MiNEN                             3
# Name: Pathology, dtype: int64

# %%
#gbc_patients["Tumour_grade_final"].value_counts()

# %%
gbc_patients["Cancer_presentation_final"].value_counts()
# Out:
# Metastatic          354
# Incidental          189
# Locally advanced     97
# Not known             2
# Name: Cancer_presentation_final, dtype: int64

# %%
gbc_patients["Tumour_stage_final"].value_counts()
# Out:
# Stage IV     406
# Stage III     90
# Not known     76
# Stage II      43
# Stage I        4
# Stage 0        1
# Name: Tumour_stage_final, dtype: int64

# %%
#gbc_patients["TNM_classification"].value_counts()

# %%
#gbc_patients["Metastasis_final"].value_counts()

# %%
#gbc_patients["Site_metastasis"].value_counts()

# %%
gbc_patients["Mets_site_final"].value_counts()
# Out:
# Not applicable          279
# Liver                   205
# Peritoneum & Omentum     49
# Lungs                    28
# Portsite                 15
# Liver & Lungs            13
# Stomach & Intestine       7
# Liver & Bone              7
# Adrenal gland             5
# Bone                      5
# Ovary & Uterus            3
# Pancreas                  3
# Right hypochondrium       3
# Not known                 2
# FALSE                     2
# Lungs and bone            1
# Lung,Bone                 1
# Chest                     1
# Brain                     1
# Name: Mets_site_final, dtype: int64

# %%
#gbc_patients["Cholecystectomy_TMC"].value_counts()

# %%
#gbc_patients["Outside_cholecystectomy"].value_counts()

# %%
gbc_patients["Surgery_final"].value_counts()
# Out:
# No         363
# Simple     201
# Radical     92
# Partial      4
# Name: Surgery_final, dtype: int64

# %%
gbc_patients["Treatment_final"].value_counts()
# Out:
# Disease Control    416
# Palliative_care    169
# Curative            57
# Name: Treatment_final, dtype: int64

# %%
gbc_patients["Treatment_clean"].value_counts()
# Out:
# Chemotherapy                 199
# Palliative-care              136
# Surgery                      125
# Surgery-chemotherapy         100
# No                            55
# Chemo-radiotherapy             9
# Surgery-chemoradiotherapy      6
# Name: Treatment_clean, dtype: int64

# %%
gbc_patients["Treatment"].value_counts()
# Out:
# Palliative chemotherapy                                 146
# Surgery                                                 106
# Palliative                                               83
# Not Applicable                                           46
# Chemotherapy                                             42
# Surgery and chemotherapy                                 41
# Surgery-chemotherapy                                     40
# Palliative care                                          34
# Palliation                                               18
# Curative surgery                                         15
# Curative surgery, Chemotherapy                            8
# NACT                                                      6
# Not Known                                                 5
# Curative surgery & chemotherapy                           5
# Palliative Chemotherapy                                   4
# Chemotherapy, Radiotherapy                                4
# Observation                                               2
# Systemic chemotherapy                                     2
# Chemotherapy (outside)                                    2
# CTRT                                                      2
# Curative surgery & CTRT                                   2
# Adjuvant chemotherapy                                     2
# Surgery+CR-RT                                             2
# Surgery and Chemotherapy and radiotherapy                 1
# Chemotherapy and Radiotherapy                             1
# Adjuvant CTRT                                             1
# Palliative Radiation treatment                            1
# Curative                                                  1
# Not available                                             1
# Radiotherapy, chemotherapy                                1
# Radical treatment                                         1
# Not fit for chemotherapy                                  1
# Chemotherapy is risky due to  dilated cardiomyopathy      1
# Stenting and chemotherapy                                 1
# Treatment not possible                                    1
# Surgery-CTRT                                              1
# Name: Treatment, dtype: int64

# %%
#gbc_patients["COUNTRY"].value_counts()

# %%
#gbc_patients["Treatment"].value_counts()

# %%
#gbc_patients["HEIGHT"].value_counts()

# %%
#sns.histplot(gbc_patients["HEIGHT"])

# %%
#sns.histplot(gbc_patients["WEIGHT"])

# %%
#sns.histplot(gbc_patients["BSA_DETAILS"])

# %%
sns.histplot(gbc_patients["BMI_DETAILS"])
plt.xlim(0, 40)
# Out:
# (0.0, 40.0)

# %%
gbc_patients["BMI_DETAILS"].value_counts()
# Out:
# 0.00     74
# 24.22     3
# 26.53     3
# 26.38     3
# 19.31     3
#          ..
# 25.05     1
# 19.09     1
# 15.39     1
# 31.31     1
# 29.91     1
# Name: BMI_DETAILS, Length: 424, dtype: int64

# %%
#sns.histplot(gbc_patients["BILIRUBIN CONJUGATED"])

# %%
#sns.histplot(gbc_patients["BILIRUBIN UNCONJUGATED"])

# %%
sns.histplot(gbc_patients["BILIRUBIN TOTAL"])
# Out:
# <Axes: xlabel='BILIRUBIN TOTAL', ylabel='Count'>

# %%
sns.histplot(gbc_patients["AST - SGOT"])
# Out:
# <Axes: xlabel='AST - SGOT', ylabel='Count'>

# %%
sns.histplot(gbc_patients["ALT - SGPT"])
# Out:
# <Axes: xlabel='ALT - SGPT', ylabel='Count'>

# %%
columns_to_drop = ["MR_NO", "Comorbidities_final", "Tumour_grade_final","TNM_classification","Metastasis_final","Site_metastasis","Outside_cholecystectomy","Cholecystectomy_TMC","Treatment_clean","Treatment","COUNTRY", "STATE_NAME", "GENDER", "CITY_NAME", "PINCODE", "First_Visit_Date", "HEIGHT", "WEIGHT", "BSA_DETAILS","Diabetes_final", "BILIRUBIN UNCONJUGATED", "BILIRUBIN CONJUGATED", "CREATININE_from_UnC_test", "UREA_from_UnC_test", "ESTIMATED AVERAGE GLUCOSE (eAG)", "HbA1c", "CREATININE_from_CREATININE_test" ]

# %%
gbc_patients_remain = gbc_patients.drop(columns=columns_to_drop, axis=1)

# %%
gbc_patients_remain.to_csv("gbc_only_imp_features.csv", index=False)

# %%
gbc_patients_remain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Thyroidism                 657 non-null    object
#  1   Diabetes                   659 non-null    object
#  2   HTN                        659 non-null    object
#  3   Family_cancer_history      657 non-null    object
#  4   ECOG_final                 660 non-null    object
#  5   Gall_stone_final           657 non-null    object
#  6   Pathology                  698 non-null    object
#  7   Cancer_presentation_final  642 non-null    object
#  8   Tumour_stage_final         620 non-null    object
#  9   Mets_site_final            630 non-null    object
#  10  Surgery_final              660 non-null    object
#  11  Treatment_final            642 non-null    object
#  12  Status                     584 non-null    object
#  13  Date_event                 434 non-null    datetime64[ns]
#  14  Date_diagnosis             653 non-null    datetime64[ns]
#  15  AGE                        698 non-null    int64
#  16  BMI_DETAILS                566 non-null    float64
#  17  BILIRUBIN TOTAL            425 non-null    float64
#  18  AST - SGOT                 425 non-null    float64
#  19  ALT - SGPT                 424 non-null    float64
#  20  ALK PHOS [ALP]             425 non-null    float64
#  21  GAMMA GT                   423 non-null    float64
#  22  ALBUMIN                    424 non-null    float64
# dtypes: datetime64[ns](2), float64(7), int64(1), object(13)
# memory usage: 125.5+ KB

# %% [markdown]
# **Total no. of patients with defined "Status" = 584"**

# %% [markdown]
# **No. of patients with defined "Date_event"?**

# %%
gbc_patients["Date_event"].count()
# Out:
# 434

# %% [markdown]
# **Total no. of patients with defined "Date_event" = 434**

# %%
gbc_patients["Date_diagnosis"].count()
# Out:
# 653

# %%
df = gbc_patients[gbc_patients["Status"]=="No"]

# %%
df["Surgery_final"]
# Out:
# 47    Simple
# Name: Surgery_final, dtype: object

# %% [markdown]
# ### Filtering the data on the basis of defined "Status", "Data_event" and Date_diagnosis.

# %%
filtered_data = gbc_patients.dropna(subset=[ 'Status','Date_event', 'Date_diagnosis'])
filtered_data.shape
print(filtered_data["Status"].value_counts())
print(filtered_data["Tumour_stage_final"].value_counts())
# Out:
# Dead    425
# No        1
# Name: Status, dtype: int64
# Stage IV     278
# Stage III     55
# Not known     38
# Stage II      14
# Name: Tumour_stage_final, dtype: int64

# %%
filtered_data1 = gbc_patients.dropna(subset=[ 'Status','Date_event'])
filtered_data1.shape
filtered_data1["Status"].value_counts()
# Out:
# Dead    433
# No        1
# Name: Status, dtype: int64

# %%
filtered_data2 = gbc_patients.dropna(subset=[ 'Status','Date_diagnosis'])
filtered_data2.shape
filtered_data2["Status"].value_counts()
# Out:
# Dead         443
# Not Known     63
# Alive         33
# Live          26
# No             1
# Name: Status, dtype: int64

# %%
filtered_data3 = gbc_patients.dropna(subset=[ 'Date_event','Date_diagnosis'])
filtered_data3.shape
filtered_data3["Status"].value_counts()
# Out:
# Dead    425
# No        1
# Name: Status, dtype: int64

# %% [markdown]
# ### LIVER FUNCTION TEST ###

# %%
lft = gbc_patients[["BILIRUBIN TOTAL", "AST - SGOT", "ALT - SGPT", "ALK PHOS [ALP]", "GAMMA GT", "ALBUMIN"]]

# %%
lft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 698 entries, 0 to 697
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   BILIRUBIN TOTAL  425 non-null    float64
#  1   AST - SGOT       425 non-null    float64
#  2   ALT - SGPT       424 non-null    float64
#  3   ALK PHOS [ALP]   425 non-null    float64
#  4   GAMMA GT         423 non-null    float64
#  5   ALBUMIN          424 non-null    float64
# dtypes: float64(6)
# memory usage: 32.8 KB

# %%
import pandas as pd

# Assuming your DataFrame is named 'lft'
# Replace 'lft' with the actual name if it's different in your case

# Compute median for each feature
median_values = lft.median()

# Compute IQR for each feature
Q1 = lft.quantile(0.25)
Q3 = lft.quantile(0.75)
IQR = Q3 - Q1

# Count non-null values for each feature
non_null_count = lft.count()

# Format quartile values for display
Q1_str = Q1.apply(lambda x: f'{x:.2f}')
Q3_str = Q3.apply(lambda x: f'{x:.2f}')

# Create a DataFrame to display the results in tabular form
result_table = pd.DataFrame({
    "Patient's Count": non_null_count.values,
    'Feature': median_values.index,
    'Median': median_values.values,
    'Q1 (0.25)': Q1_str.values,
    'Q3 (0.75)': Q3_str.values,
    'IQR': IQR.values
})

# Display the result
print(result_table)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       1 import pandas as pd
#       3 # Assuming your DataFrame is named 'lft'
#       4 # Replace 'lft' with the actual name if it's different in your case
#       5
#       6 # Compute median for each feature
# ----> 7 median_values = lft.median()
#       9 # Compute IQR for each feature
#      10 Q1 = lft.quantile(0.25)
#
# NameError: name 'lft' is not defined

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Assuming your DataFrame is named 'lft'
# Replace 'lft' with the actual name if it's different in your case

# Feature to plot
feature_to_plot = 'BILIRUBIN TOTAL'

# Abnormal value threshold
abnormal_threshold = 2.0

# Create a figure and axis
fig, ax = plt.subplots()

# Plot histogram
n, bins, patches = ax.hist(lft[feature_to_plot].dropna(), bins=30, alpha=0.7, color='blue', edgecolor='black')

# Find the indices of bins that are above and below the abnormal threshold
abnormal_indices = lft[lft[feature_to_plot] >= abnormal_threshold].index
normal_indices = lft[lft[feature_to_plot] < abnormal_threshold].index

# Calculate the percentage of observations that are normal and abnormal
percentage_normal = (len(normal_indices) / len(lft)) * 100
percentage_abnormal = (len(abnormal_indices) / len(lft)) * 100

# Shade regions with different colors
for patch, index in zip(patches, bins):
    if index >= abnormal_threshold:
        patch.set_facecolor('red')
    else:
        patch.set_facecolor('blue')

# Add labels and title
ax.set_xlabel(feature_to_plot)
ax.set_ylabel('Frequency')
ax.set_title(f'Histogram of {feature_to_plot} with Abnormal Threshold')


# Show the plot
plt.show()

# %%
#########

# %%
abnormal_indices = lft[lft["BILIRUBIN TOTAL"] >= 2]

# %%
len(abnormal_indices)
# Out:
# 129

# %%
129/425
# Out:
# 0.3035294117647059

# %%
###########

# %% [markdown]
# **Total no. of patients taken into analysis will be = 426 patients with defined "Status", "Date_event", "Date_diagnosis".**

# %% [markdown]
# ***checking the "Status" of available data***

# %%
# FILTERED DATA FROM AFTER REMOVING THE UNNECESSARY VARIABLES

# %%
filtered_data = gbc_patients_remain

# %%
filtered_data = gbc_patients_remain.dropna(subset=[ 'Status','Date_event', 'Date_diagnosis'])
filtered_data.shape
print(filtered_data["Status"].value_counts())
print(filtered_data["Tumour_stage_final"].value_counts())
# Out:
# Dead    425
# No        1
# Name: Status, dtype: int64
# Stage IV     278
# Stage III     55
# Not known     38
# Stage II      14
# Name: Tumour_stage_final, dtype: int64

# %%
filtered_data["Status"].value_counts()
# Out:
# Dead    425
# No        1
# Name: Status, dtype: int64

# %%
gbc_patients_remain.shape
# Out:
# (698, 23)

# %% [markdown]
# **Total no. of Patients with "Status" = Dead are 425 and "Status" = No is 1.**

# %% [markdown]
# #### Checking the "Date_event" and "Date_diagnosis" in order to check the range of "Datetime" feature for our data

# %%
print(filtered_data['Date_event'].describe())
print('*********************************')
print(filtered_data['Date_diagnosis'].describe())
# Out:
# count                     426
# unique                    323
# top       2019-06-15 00:00:00
# freq                        7
# first     2017-01-02 00:00:00
# last      2021-09-07 00:00:00
# Name: Date_event, dtype: object
# *********************************
# count                     426
# unique                    329
# top       2018-05-15 00:00:00
# freq                        5
# first     2008-08-15 00:00:00
# last      2020-02-05 00:00:00
# Name: Date_diagnosis, dtype: object
# C:\Users\sriva\AppData\Local\Temp\ipykernel_45344\1738299165.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(filtered_data['Date_event'].describe())
# C:\Users\sriva\AppData\Local\Temp\ipykernel_45344\1738299165.py:3: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   print(filtered_data['Date_diagnosis'].describe())

# %% [markdown]
# **The oldest date in "Date_event" feature = 2017-01-02 i.e. 2nd January 2017.**
#
# **The latest date in "Date_event" feature = 2021-09-07 i.e. 7th September 2021.**
#
# **The oldest date in "Date_diagnosis" feature = 2008-08-15 i.e. 15th August 2008.**
#
# **The latest date in "Date_diagnosis" feature = 2020-02-05 i.e. 5th February 2020.**

# %% [markdown]
# **Missing values analysis in our Filtered Data**

# %%
# Check the total missing values in each column.
print("Total NULL Values in each columns")
print("**************************************")
print(filtered_data.isnull().sum())
# Out:
# Total NULL Values in each columns
# **************************************
# Thyroidism                    19
# Diabetes                      17
# HTN                           17
# Family_cancer_history         19
# ECOG_final                    16
# Gall_stone_final              18
# Pathology                      0
# Cancer_presentation_final     25
# Tumour_stage_final            41
# Mets_site_final               28
# Surgery_final                 16
# Treatment_final               31
# Status                         0
# Date_event                     0
# Date_diagnosis                 0
# AGE                            0
# BMI_DETAILS                   76
# BILIRUBIN TOTAL              153
# AST - SGOT                   153
# ALT - SGPT                   154
# ALK PHOS [ALP]               153
# GAMMA GT                     154
# ALBUMIN                      153
# dtype: int64

# %% [markdown]
# **A lot of variables have significant no. of missing data**

# %% [markdown]
# ### Checking the no. of different categories in every categorical variables and their respective counts

# %%
# Filter columns with object data type
categorical_columns = filtered_data.select_dtypes(include=['object']).columns

# Calculate counts of each category in categorical features
category_counts = {}

for column in categorical_columns:
    counts = filtered_data[column].value_counts()
    category_counts[column] = counts

# Print the counts of each category in categorical features
for column, counts in category_counts.items():
    print(f'Counts for {column}:')
    print(counts)
    print()
# Out:
# Counts for Thyroidism:
# No                305
# Not known          67
# Hypothyroidism     35
# Name: Thyroidism, dtype: int64
#
# Counts for Diabetes:
# No           240
# Yes          103
# Not known     66
# Name: Diabetes, dtype: int64
#
# Counts for HTN:
# No           207
# Yes          141
# Not known     61
# Name: HTN, dtype: int64
#
# Counts for Family_cancer_history:
# Not known    216
# No           154
# Yes           37
# Name: Family_cancer_history, dtype: int64
#
# Counts for ECOG_final:
# 1            221
# 2             92
# 3             37
# Not known     30
# 4             16
# 0             14
# Name: ECOG_final, dtype: int64
#
# Counts for Gall_stone_final:
# Yes          171
# Not known    119
# No           117
# Polyp          1
# Name: Gall_stone_final, dtype: int64
#
# Counts for Pathology:
# Adenocarcinoma                  360
# Carcinoma                        31
# Adenosquamous carcinoma          14
# Neuroendocrine carcinoma          7
# Others                            7
# Mucinous adenocarcinoma           3
# MiNEN                             2
# ICPN with invasive carcinoma      2
# Name: Pathology, dtype: int64
#
# Counts for Cancer_presentation_final:
# Metastatic          240
# Incidental           99
# Locally advanced     62
# Name: Cancer_presentation_final, dtype: int64
#
# Counts for Tumour_stage_final:
# Stage IV     278
# Stage III     55
# Not known     38
# Stage II      14
# Name: Tumour_stage_final, dtype: int64
#
# Counts for Mets_site_final:
# Not applicable          158
# Liver                   143
# Peritoneum & Omentum     34
# Lungs                    16
# Liver & Lungs             9
# Portsite                  8
# Liver & Bone              7
# Stomach & Intestine       5
# Pancreas                  3
# Ovary & Uterus            3
# Adrenal gland             2
# Not known                 2
# Right hypochondrium       2
# Lungs and bone            1
# Bone                      1
# Chest                     1
# FALSE                     1
# Lung,Bone                 1
# Brain                     1
# Name: Mets_site_final, dtype: int64
#
# Counts for Surgery_final:
# No         250
# Simple     114
# Radical     43
# Partial      3
# Name: Surgery_final, dtype: int64
#
# Counts for Treatment_final:
# Disease Control    253
# Palliative_care    113
# Curative            29
# Name: Treatment_final, dtype: int64
#
# Counts for Status:
# Dead    425
# No        1
# Name: Status, dtype: int64

# %% [markdown]
# #### Creating a new feature named as "Time_overall_study" in 'months' by using the logic =
#
# **"Time_overall_study = "Date_event" - "Date_diagnosis"**

# %%
# Calculate the difference of Date_event and Date_diagnosis in months
filtered_data['Time_overall_study'] = ((filtered_data['Date_event'] - filtered_data['Date_diagnosis']) / np.timedelta64(1, 'M')).astype(float)

filtered_data.head()
# Out:
# C:\Users\sriva\AppData\Local\Temp\ipykernel_45344\2160711339.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['Time_overall_study'] = ((filtered_data['Date_event'] - filtered_data['Date_diagnosis']) / np.timedelta64(1, 'M')).astype(float)
#        Thyroidism   Diabetes  HTN Family_cancer_history ECOG_final  \
# 0              No         No  Yes                    No          1
# 4              No         No   No                    No          1
# 5              No         No  Yes                    No          2
# 7              No        Yes  Yes             Not known          1
# 8  Hypothyroidism  Not known  Yes             Not known  Not known
#
#   Gall_stone_final       Pathology Cancer_presentation_final  \
# 0              Yes  Adenocarcinoma                Incidental
# 4        Not known  Adenocarcinoma                Metastatic
# 5              Yes  Adenocarcinoma                Metastatic
# 7              Yes           MiNEN                Incidental
# 8              Yes  Adenocarcinoma          Locally advanced
#
#   Tumour_stage_final Mets_site_final  ... Date_diagnosis AGE BMI_DETAILS  \
# 0           Stage IV  Not applicable  ...     2016-12-23  60       24.93
# 4           Stage IV           Liver  ...     2017-01-30  58       22.55
# 5           Stage IV           Liver  ...     2017-01-24  62        0.00
# 7           Stage II  Not applicable  ...     2017-01-04  62       20.22
# 8          Not known  Not applicable  ...     2017-02-16  77       24.15
#
#   BILIRUBIN TOTAL AST - SGOT  ALT - SGPT  ALK PHOS [ALP]  GAMMA GT  ALBUMIN  \
# 0             0.5       23.0        28.0           147.0      21.0      4.7
# 4             0.4      348.0        78.0           206.0     481.0      3.2
# 5             NaN        NaN         NaN             NaN       NaN      NaN
# 7             1.0       36.0        31.0           108.0      21.0      4.6
# 8            20.5      286.0       130.0           492.0     209.0      2.6
#
#    Time_overall_study
# 0           24.246904
# 4           11.860613
# 5           17.248814
# 7           23.852646
# 8           12.846260
#
# [5 rows x 24 columns]

# %%
filtered_data["Time_overall_study"].min(), filtered_data["Time_overall_study"].max()
# Out:
# (-8.01659171646235, 147.22273557978602)

# %% [markdown]
# **Negative overall study time period is not possible, therefore having a look at that partiicular datapoint**

# %%
# Replace 'column_name' with the actual name of your column
row = filtered_data[filtered_data['Time_overall_study'] == -8.01659171646235]

print(row["Status"])
print(row["Date_event"])
print(row["Date_diagnosis"])
# Out:
# 657    Dead
# Name: Status, dtype: object
# 657   2019-02-23
# Name: Date_event, dtype: datetime64[ns]
# 657   2019-10-25
# Name: Date_diagnosis, dtype: datetime64[ns]

# %% [markdown]
# **Since the status of this person is dead therefore Time_overall_study for this person being negative resembles to Date of event is past as compared to the Date of diagnosis which is a false data i.e. not possible. A patient who has already died cannot have a Diagnosis in future. Therefore removing this false data from our analysis.**
#
# **Date_event = 23 feb 2019 and Date_diagnosis = 25th october 2019, which is not possible**
#
# **Deleting this particular observation from our analysis**

# %%
#Time_overall_study feature
value_to_delete = -8.01659171646235

# Delete the row with the specified value
filtered_data = filtered_data[filtered_data['Time_overall_study'] != value_to_delete]

filtered_data.shape
# Out:
# (425, 24)

# %%
data=filtered_data.copy()

# %% [markdown]
# ### Replacing "Dead" Status by 1 and "No" by 0 in "Status" feature in order to make our analysis easier.

# %%
# Mapping of values to be replaced
status_mapping = {'Dead': 1, 'No': 0}

# Replace values in the "Status" column
data['Status'] = data['Status'].replace(status_mapping)

# %%
data[["Status"]].value_counts() #counts for respective categories in "Status" feature. 425 patients = Dead, 1 patient = No.
# Out:
# Status
# 1         424
# 0           1
# dtype: int64

# %% [markdown]
# ### Exploratory Data Analysis
#
# As per the plots dsplayed in the research paper, considering only three variables for the survival curves as of now.
#
# ### 1. Univariate Analysis of Categorical variables
#
# Three variables considered in the analysis -
#
# 1. Tumour_stage_final
# 2. Surgery_final
# 3. Treatment_final

# %%
category_list = ['Tumour_stage_final', 'Surgery_final', 'Treatment_final', 'Cancer_presentation_final']

def plotUnivariateAnalysis(data_frame, category_list, rows, cols, figsize):
    fig, axes = plt.subplots(rows, cols, figsize=figsize)
    axes = axes.flatten()
    
    for i, category in enumerate(category_list):
        ax = axes[i]
        counts = data_frame[category].value_counts()
        missing_count = data_frame[category].isnull().sum()
        total_count = len(data_frame)
        
        counts.plot(kind='bar', ax=ax)
        
        ax.set_title(f'{category} Distribution')
        ax.set_xlabel(category)
        ax.set_ylabel('Frequency')
        
        # Calculate and display percentage text on the bars
        total_valid_count = total_count 
        for rect in ax.patches:
            height = rect.get_height()
            ax.annotate(f'{height / total_valid_count:.2%}', 
                        xy=(rect.get_x() + rect.get_width() / 2, height), 
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points", 
                        ha='center', va='bottom')
        
        # Display percentage of missing values above the plot
        ax.annotate(f"Missing: {missing_count}/{total_count} ({missing_count / total_count:.2%})", 
                    xy=(0.5, 0.95), 
                    xycoords='axes fraction', 
                    ha='center', fontsize=10, color='red')
    
    # Hide any unused subplots
    for i in range(len(category_list), rows * cols):
        fig.delaxes(axes[i])
    
    plt.tight_layout()
    plt.show()

# %%
# PLOTS FOR THE FILTERED DATA
# Call the function to create the grid of plots
plotUnivariateAnalysis(data_frame=filtered_data, 
                       category_list=category_list, 
                       rows=2, 
                       cols=3, 
                       figsize=(18, 10))

# %%
# PLOTS FOR THE WHOLE DATA
# Call the function to create the grid of plots
plotUnivariateAnalysis(data_frame=data, 
                       category_list=category_list, 
                       rows=2, 
                       cols=3, 
                       figsize=(18, 10))

# %%
data["Tumour_stage_final"].value_counts()
# Out:
# Stage IV     277
# Stage III     55
# Not known     38
# Stage II      14
# Name: Tumour_stage_final, dtype: int64

# %%
import matplotlib.pyplot as plt
import pandas as pd

category_list = ['Tumour_stage_final', 'Surgery_final', 'Treatment_final', 'Cancer_presentation_final']

def plotUnivariateAnalysis(data_frame, category_list, rows, cols, figsize):
    fig, axes = plt.subplots(rows, cols, figsize=figsize)
    axes = axes.flatten()
    
    # Define the desired order for each category
    category_order = {
        'Tumour_stage_final': ['Stage II', 'Stage III', 'Stage IV', 'Not known'],
        'Surgery_final': ['No', 'Simple', 'Partial', 'Radical'],
        'Treatment_final': ['Disease Control', 'Curative', 'Palliative_Care'],
        'Cancer_presentation_final': ['Incidental', 'Locally advanced', 'Metastatic']
    }
    
    for i, category in enumerate(category_list):
        ax = axes[i]
        counts = data_frame[category].value_counts().reindex(category_order[category])
        missing_count = data_frame[category].isnull().sum()
        total_count = len(data_frame)
        
        counts.plot(kind='bar', ax=ax)
        
        ax.set_title(f'{category} Distribution')
        ax.set_xlabel(category)
        ax.set_ylabel('Frequency')
        
        # Calculate and display percentage text on the bars
        total_valid_count = total_count 
        for rect in ax.patches:
            height = rect.get_height()
            ax.annotate(f'{height / total_valid_count:.2%}', 
                        xy=(rect.get_x() + rect.get_width() / 2, height), 
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points", 
                        ha='center', va='bottom')
        
        # Display percentage of missing values above the plot
        ax.annotate(f"Missing: {missing_count}/{total_count} ({missing_count / total_count:.2%})", 
                    xy=(0.5, 0.95), 
                    xycoords='axes fraction', 
                    ha='center', fontsize=10, color='red')
    
    # Hide any unused subplots
    for i in range(len(category_list), rows * cols):
        fig.delaxes(axes[i])
    
    plt.tight_layout()
    plt.show()


# Example usage:
# Assuming 'filtered_data' is your DataFrame
plotUnivariateAnalysis(data_frame=data, 
                       category_list=category_list, 
                       rows=2, 
                       cols=2, 
                       figsize=(18, 10))

# %%
data["Surgery_final"].value_counts()
# Out:
# No         249
# Simple     114
# Radical     43
# Partial      3
# Name: Surgery_final, dtype: int64

# %%
data["Tumour_stage_final"].value_counts()
# Out:
# Stage IV     277
# Stage III     55
# Not known     38
# Stage II      14
# Name: Tumour_stage_final, dtype: int64

# %% [markdown]
# #### <font color = brown>Data Insight 1:</font>
#
# **`1. ~72% of the population under study had stage 4 tumour, while ~14% had stage 3 tumour, ~9.8% did not have any known stage of tumour, ~3.6% had stage 2 tumour and 9.62% data is missing.`**
#
# **`2. ~61% of the population under study had No surgery, ~27% had simple cholecystectomy, ~10.5% patients had radical cholecystectomy, ~0.73% had partial type and ~3.76% data is missing.`**
#
# **`3. ~64% of the population under study had disease control type treatment,~28% had palliative care, ~7.3% had curative treatment and ~7.28% data is missing.`**

# %% [markdown]
# ### Survival w.r.t Tumour stage

# %%
##Checking for Missing values in the "Tumour_stage_final" column

# %%
data["Tumour_stage_final"].isnull().sum()
# Out:
# 41

# %% [markdown]
# **41 missing values are present in "Tumour_stage_final" column**

# %%
data["Tumour_stage_final"].value_counts()
# Out:
# Stage IV     277
# Stage III     55
# Not known     38
# Stage II      14
# Name: Tumour_stage_final, dtype: int64

# %%
# Assign missing values as "Missing_Data"
data['Tumour_stage_final'] = data['Tumour_stage_final'].fillna("Missing_Data")

# %%
data['Tumour_stage_final'].value_counts() #41 missing values are to a new category named as Missing_Data
# Out:
# Stage IV        277
# Stage III        55
# Missing_Data     41
# Not known        38
# Stage II         14
# Name: Tumour_stage_final, dtype: int64

# %%
# Extract two features and create a new DataFrame
selected_features = ['Tumour_stage_final', 'Status']
df = data[selected_features]
df["Status"].value_counts()
# Out:
# 1    424
# 0      1
# Name: Status, dtype: int64

# %%
# Group by "Tumour_stage_final" and calculate the counts of 1s and 0s
grouped = df.groupby(['Tumour_stage_final', 'Status']).size().unstack()

# Plot the bar plot
ax = grouped.plot(kind='bar', stacked=True)
plt.title("Number of Patients' Status by Tumour Stage")
plt.xlabel("Tumour Stage")
plt.ylabel("Number of Patients")
plt.legend(['Not Dead', 'Dead'], loc='upper right')
plt.show()

# %% [markdown]
# **1 Patient who is not dead (blue colour) in our dataset belongs to "Not known" category of the "Tumour_stage_final" feature.**

# %% [markdown]
# ### KAPLAN-MEIER Survival Curve

# %%
#!pip install lifelines
#!pip install scikit-survival

# %%
data.columns
# Out:
# Index(['Thyroidism', 'Diabetes', 'HTN', 'Family_cancer_history', 'ECOG_final',
#        'Gall_stone_final', 'Pathology', 'Cancer_presentation_final',
#        'Tumour_stage_final', 'Mets_site_final', 'Surgery_final',
#        'Treatment_final', 'Status', 'Date_event', 'Date_diagnosis', 'AGE',
#        'BMI_DETAILS', 'BILIRUBIN TOTAL', 'AST - SGOT', 'ALT - SGPT',
#        'ALK PHOS [ALP]', 'GAMMA GT', 'ALBUMIN', 'Time_overall_study'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 425 entries, 0 to 695
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Thyroidism                 406 non-null    object
#  1   Diabetes                   408 non-null    object
#  2   HTN                        408 non-null    object
#  3   Family_cancer_history      406 non-null    object
#  4   ECOG_final                 409 non-null    object
#  5   Gall_stone_final           407 non-null    object
#  6   Pathology                  425 non-null    object
#  7   Cancer_presentation_final  400 non-null    object
#  8   Tumour_stage_final         425 non-null    object
#  9   Mets_site_final            397 non-null    object
#  10  Surgery_final              409 non-null    object
#  11  Treatment_final            394 non-null    object
#  12  Status                     425 non-null    int64
#  13  Date_event                 425 non-null    datetime64[ns]
#  14  Date_diagnosis             425 non-null    datetime64[ns]
#  15  AGE                        425 non-null    int64
#  16  BMI_DETAILS                349 non-null    float64
#  17  BILIRUBIN TOTAL            272 non-null    float64
#  18  AST - SGOT                 272 non-null    float64
#  19  ALT - SGPT                 271 non-null    float64
#  20  ALK PHOS [ALP]             272 non-null    float64
#  21  GAMMA GT                   271 non-null    float64
#  22  ALBUMIN                    272 non-null    float64
#  23  Time_overall_study         425 non-null    float64
# dtypes: datetime64[ns](2), float64(8), int64(2), object(12)
# memory usage: 83.0+ KB

# %% [markdown]
# #### converting "Status" feature into boolean for survival analysis

# %%
# data
data["Status"] = data["Status"].astype(bool)

# %%
from lifelines import KaplanMeierFitter
#data
df = data
# Initialize KaplanMeierFitter
kmf = KaplanMeierFitter()

# Fit the Kaplan-Meier estimator
kmf.fit(df['Time_overall_study'], event_observed=df['Status'])

# Create a new figure and axes
fig, ax = plt.subplots()

# Plot the Kaplan-Meier survival curve
kmf.plot(ax=ax)

# Plot censored points
censored_data = df[df['Status'] == 0]
ax.scatter(censored_data['Time_overall_study'], kmf.predict(censored_data['Time_overall_study']),
           label='Censored', c='red', marker='x')

# Display the risk data table
risk_table = kmf.event_table
print(risk_table)

# Customize the plot
plt.title("Kaplan-Meier Survival Curve")
plt.xlabel("Time")
plt.ylabel("Survival Probability")
plt.legend()
plt.show()
# Out:
#             removed  observed  censored  entrance  at_risk
# event_at
# 0.000000          1         1         0       425      425
# 0.032855          1         1         0         0      424
# 0.065710          2         2         0         0      423
# 0.098565          1         1         0         0      421
# 0.131420          1         1         0         0      420
# ...             ...       ...       ...       ...      ...
# 82.925727         1         1         0         0        5
# 97.546151         1         1         0         0        4
# 106.975503        1         1         0         0        3
# 107.172632        1         1         0         0        2
# 147.222736        1         1         0         0        1
#
# [320 rows x 5 columns]

# %%
from lifelines import KaplanMeierFitter
kmf = KaplanMeierFitter()

Time = data["Time_overall_study"]
Event = data["Status"]

kmf.fit(Time, event_observed=Event)
# Out:
# <lifelines.KaplanMeierFitter:"KM_estimate", fitted with 425 total observations, 1 right-censored observations>

# %%
# Perform Kaplan-Meier survival analysis
kmf = KaplanMeierFitter().fit(data["Time_overall_study"], data["Status"])

# Create a larger figure
plt.figure(figsize=(10, 6))  # Adjust the width and height as needed

# Plot the Kaplan-Meier survival function with at-risk counts
kmf.plot_survival_function(at_risk_counts=True)

# Plot censored data points
censored_data = data[data["Status"] == 0]
plt.scatter(censored_data["Time_overall_study"], kmf.predict(censored_data["Time_overall_study"]),
            marker='x', color='red', s=50, label='Censored')

# Add title and labels to the plot
plt.title("Kaplan-Meier Survival Analysis for overall cohort")
plt.xlabel("Time")
plt.ylabel("Survival Probability")
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming "data" is a DataFrame containing "Time_overall_study" and "Status" columns
# Add your data loading and processing steps here

# Create a larger figure
plt.figure(figsize=(12, 6))

# Box plot for "Time_overall_study"
plt.subplot(1, 2, 1)
sns.boxplot(x=data["Status"], y=data["Time_overall_study"], palette="Set1")
plt.title("Box Plot for Time_overall_study")
plt.xlabel("Status (False = Alive: Censored, True = Dead: Event)")
plt.ylabel("Time_overall_study")

# Box plot for other variables if needed
# Example: sns.boxplot(x=data["Status"], y=data["Another_Variable"], palette="Set2")
# plt.subplot(1, 2, 2)
# plt.title("Box Plot for Another_Variable")
# plt.xlabel("Status (0: Censored, 1: Event)")
# plt.ylabel("Another_Variable")

# Adjust layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
#Median time of survival
kmf.median_survival_time_
# Out:
# 7.129509846198074

# %% [markdown]
# **The overall median survival time for the data available is 7.12 months**

# %% [markdown]
# ### Confidence Interval for overall Median survival time

# %%
from lifelines.utils import median_survival_times
median_ci = median_survival_times(kmf.confidence_interval_)
median_ci
# Out:
#      KM_estimate_lower_0.95  KM_estimate_upper_0.95
# 0.5                6.439557                8.180866

# %% [markdown]
# **The 95% confidence interval for the median survival time = 6.43 months to 8.18 months**

# %% [markdown]
# ### Survival Curve based on Stages of Tumour

# %%
data["Tumour_stage_final"].value_counts()
# Out:
# Stage IV        277
# Stage III        55
# Missing_Data     41
# Not known        38
# Stage II         14
# Name: Tumour_stage_final, dtype: int64

# %%
data["Tumour_stage_final"].isnull().sum()
# Out:
# 0

# %% [markdown]
# **0 Missing values in "Tumour_stage_final" feature**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from lifelines import KaplanMeierFitter
from lifelines.utils import survival_table_from_events


# data
df = data[["Tumour_stage_final", "Status", "Time_overall_study"]]

# Perform Kaplan-Meier survival analysis for each category
kmf = KaplanMeierFitter()

# Create a larger figure
plt.figure(figsize=(10, 6))  # Adjust the width and height as needed

for category in df["Tumour_stage_final"].unique():
    subset = df[df["Tumour_stage_final"] == category]
    kmf.fit(subset["Time_overall_study"], event_observed=subset["Status"], label=category)

    # Plot the Kaplan-Meier curve
    kmf.plot(ci_show=False)

    # Calculate and print median survival time
    median_survival_time = kmf.median_survival_time_
    print(f"Median survival time for {category}: {median_survival_time:.2f} months")

    # Plot censored data points
    censored_data = subset[subset["Status"] == 0]
    plt.scatter(censored_data["Time_overall_study"], kmf.predict(censored_data["Time_overall_study"]),
            marker='x', color='black', s=50, label=f'Censored - {category}')
    
    # Calculate the risk table
    event_table = survival_table_from_events(subset["Time_overall_study"], subset["Status"])
    print(f"Risk table for {category}:\n{event_table}")
    

    
# Add title and labels to the plot
plt.title("Kaplan-Meier Survival Analysis by Tumour Stage")
plt.xlabel("Time (months)")
plt.ylabel("Survival Probability")
plt.legend()

# Change x-axis scale to 5 months
plt.xticks(np.arange(0, 151, 10), rotation=45)

# Show the plot
plt.show()
# Out:
# Median survival time for Stage IV: 6.44 months
# Risk table for Stage IV:
#             removed  observed  censored  entrance  at_risk
# event_at
# 0.000000          0         0         0       277      277
# 0.032855          1         1         0         0      277
# 0.065710          1         1         0         0      276
# 0.131420          1         1         0         0      275
# 0.295694          1         1         0         0      274
# ...             ...       ...       ...       ...      ...
# 49.216616         1         1         0         0        5
# 82.925727         1         1         0         0        4
# 97.546151         1         1         0         0        3
# 107.172632        1         1         0         0        2
# 147.222736        1         1         0         0        1
#
# [224 rows x 5 columns]
# Median survival time for Stage II: 13.34 months
# Risk table for Stage II:
#            removed  observed  censored  entrance  at_risk
# event_at
# 0.000000         0         0         0        14       14
# 0.919937         1         1         0         0       14
# 1.872728         1         1         0         0       13
# 2.069858         1         1         0         0       12
# 9.330787         1         1         0         0       11
# 9.790755         1         1         0         0       10
# 11.926323        1         1         0         0        9
# 13.207663        1         1         0         0        8
# 13.339083        1         1         0         0        7
# 15.540360        1         1         0         0        6
# 17.248814        1         1         0         0        5
# 20.862851        1         1         0         0        4
# 23.852646        1         1         0         0        3
# 27.170989        1         1         0         0        2
# 38.144520        1         1         0         0        1
# Median survival time for Not known: 9.07 months
# Risk table for Not known:
#             removed  observed  censored  entrance  at_risk
# event_at
# 0.000000          0         0         0        38       38
# 0.624243          1         1         0         0       38
# 1.412760          1         1         0         0       37
# 2.496971          1         1         0         0       36
# 2.562681          1         1         0         0       35
# 2.891230          1         1         0         0       34
# 3.548327          1         1         0         0       33
# 4.041151          1         1         0         0       32
# 4.632539          1         1         0         0       31
# 5.256781          1         1         0         0       30
# 5.289636          1         1         0         0       29
# 5.651040          1         1         0         0       28
# 6.143863          1         1         0         0       27
# 6.340993          1         1         0         0       26
# 6.965235          1         1         0         0       25
# 7.030945          1         1         0         0       24
# 7.096655          1         1         0         0       23
# 7.293784          1         1         0         0       22
# 7.950882          1         1         0         0       21
# 9.067948          1         1         0         0       20
# 11.367790         1         1         0         0       19
# 11.992033         1         1         0         0       18
# 12.320582         1         1         0         0       17
# 12.681985         1         1         0         0       16
# 12.846260         1         1         0         0       15
# 13.766196         1         1         0         0       14
# 14.456149         1         1         0         0       13
# 16.361732         1         1         0         0       12
# 17.511653         1         1         0         0       11
# 18.792994         1         1         0         0       10
# 19.778640         1         1         0         0        9
# 20.172899         1         1         0         0        8
# 21.355675         1         1         0         0        7
# 22.505596         1         1         0         0        6
# 26.152488         1         1         0         0        5
# 28.518039         1         1         0         0        4
# 29.010863         1         1         0         0        3
# 36.370357         1         0         1         0        2
# 106.975503        1         1         0         0        1
# Median survival time for Stage III: 9.69 months
# Risk table for Stage III:
#            removed  observed  censored  entrance  at_risk
# event_at
# 0.000000         0         0         0        55       55
# 0.755662         1         1         0         0       55
# 0.821372         1         1         0         0       54
# 0.985647         1         1         0         0       53
# 1.642744         1         1         0         0       52
# 2.168422         2         2         0         0       51
# 2.332697         1         1         0         0       49
# 3.154069         1         1         0         0       48
# 3.186924         2         2         0         0       47
# 3.318343         1         1         0         0       45
# 3.351198         1         1         0         0       44
# 3.844021         1         1         0         0       43
# 4.303990         1         1         0         0       42
# 4.402554         1         1         0         0       41
# 4.895378         1         1         0         0       40
# 6.373848         1         1         0         0       39
# 6.538122         1         1         0         0       38
# 6.932381         1         1         0         0       37
# 7.030945         1         1         0         0       36
# 7.556623         2         2         0         0       35
# 8.180866         1         1         0         0       33
# 8.673689         1         1         0         0       32
# 9.035093         1         1         0         0       31
# 9.100803         1         1         0         0       30
# 9.133658         1         1         0         0       29
# 9.692191         1         1         0         0       28
# 10.185014        1         1         0         0       27
# 10.283579        2         2         0         0       26
# 10.349288        1         1         0         0       24
# 10.414998        1         1         0         0       23
# 10.447853        1         1         0         0       22
# 10.973531        1         1         0         0       21
# 12.517711        1         1         0         0       20
# 13.799051        1         1         0         0       19
# 15.047537        1         1         0         0       18
# 15.244666        1         1         0         0       17
# 15.868909        1         1         0         0       16
# 16.328877        1         1         0         0       15
# 16.460297        1         1         0         0       14
# 17.215959        1         1         0         0       13
# 18.135896        1         1         0         0       12
# 18.267316        1         1         0         0       11
# 18.563010        1         1         0         0       10
# 19.877205        1         1         0         0        9
# 21.027126        1         1         0         0        8
# 22.932709        1         1         0         0        7
# 23.162693        1         1         0         0        6
# 24.476889        1         1         0         0        5
# 25.002567        1         1         0         0        4
# 25.363971        1         1         0         0        3
# 26.218197        1         1         0         0        2
# 28.090926        1         1         0         0        1
# Median survival time for Missing_Data: 6.51 months
# Risk table for Missing_Data:
#            removed  observed  censored  entrance  at_risk
# event_at
# 0.000000         1         1         0        41       41
# 0.065710         1         1         0         0       40
# 0.098565         1         1         0         0       39
# 0.394259         1         1         0         0       38
# 0.492823         1         1         0         0       37
# 0.722807         1         1         0         0       36
# 0.985647         1         1         0         0       35
# 1.051356         1         1         0         0       34
# 1.215631         1         1         0         0       33
# 1.511325         1         1         0         0       32
# 1.642744         1         1         0         0       31
# 1.839874         1         1         0         0       30
# 2.332697         1         1         0         0       29
# 2.759810         1         1         0         0       28
# 2.858375         1         1         0         0       27
# 2.891230         1         1         0         0       26
# 2.956940         1         1         0         0       25
# 3.581182         2         2         0         0       24
# 4.106861         1         1         0         0       22
# 6.505267         1         1         0         0       21
# 6.735251         1         1         0         0       20
# 6.833816         1         1         0         0       19
# 7.655188         1         1         0         0       18
# 8.837964         1         1         0         0       17
# 10.579273        1         1         0         0       16
# 11.532064        1         1         0         0       15
# 11.893468        1         1         0         0       14
# 12.419146        1         1         0         0       13
# 12.911969        1         1         0         0       12
# 13.043389        1         1         0         0       11
# 14.259020        1         1         0         0       10
# 14.653278        1         1         0         0        9
# 16.723136        1         1         0         0        8
# 18.563010        1         1         0         0        7
# 25.495390        1         1         0         0        6
# 28.715169        1         1         0         0        5
# 29.832235        1         1         0         0        4
# 30.226493        1         1         0         0        3
# 30.357913        1         1         0         0        2
# 32.624900        1         1         0         0        1

# %% [markdown]
# **Since there is only one black cross and that too on the "green" curve, it signifies that 1 observation that is censored, belongs to the "Not Known" category of the "Tumour_stage_final" feature.**
#
# **Median survival time for Stage II: 13.34 months**
#
# **Median survival time for Stage III: 9.69 months**
#
# **Median survival time for Stage IV: 6.44 months**
#
# **Median survival time for Not known: 9.07 months**
#
# **Median survival time for Missing_Data: 6.51 months**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from lifelines import KaplanMeierFitter
from lifelines.utils import survival_table_from_events


# data
df = data[["Treatment_final", "Status", "Time_overall_study"]]

# Perform Kaplan-Meier survival analysis for each category
kmf = KaplanMeierFitter()

# Create a larger figure
plt.figure(figsize=(10, 6))  # Adjust the width and height as needed

for category in df["Treatment_final"].unique():
    subset = df[df["Treatment_final"] == category]
    kmf.fit(subset["Time_overall_study"], event_observed=subset["Status"], label=category)

    # Plot the Kaplan-Meier curve
    kmf.plot(ci_show=False)

    # Calculate and print median survival time
    median_survival_time = kmf.median_survival_time_
    print(f"Median survival time for {category}: {median_survival_time:.2f} months")

    # Plot censored data points
    censored_data = subset[subset["Status"] == 0]
    plt.scatter(censored_data["Time_overall_study"], kmf.predict(censored_data["Time_overall_study"]),
            marker='x', color='black', s=50, label=f'Censored - {category}')
    
    # Calculate the risk table
    event_table = survival_table_from_events(subset["Time_overall_study"], subset["Status"])
    print(f"Risk table for {category}:\n{event_table}")
    

    
# Add title and labels to the plot
plt.title("Kaplan-Meier Survival Analysis by Treatment")
plt.xlabel("Time (months)")
plt.ylabel("Survival Probability")
plt.legend()

# Change x-axis scale to 5 months
plt.xticks(np.arange(0, 151, 10), rotation=45)

# Show the plot
plt.show()
# Out:
# Median survival time for Curative: 14.69 months
# Risk table for Curative:
#            removed  observed  censored  entrance  at_risk
# event_at
# 0.000000         0         0         0        29       29
# 0.919937         1         1         0         0       29
# 4.829668         1         1         0         0       28
# 6.275283         1         1         0         0       27
# 6.932381         1         1         0         0       26
# 7.655188         1         1         0         0       25
# 8.016592         1         1         0         0       24
# 9.133658         1         1         0         0       23
# 9.692191         1         1         0         0       22
# 10.283579        1         1         0         0       21
# 10.349288        1         1         0         0       20
# 10.447853        1         1         0         0       19
# 10.973531        1         1         0         0       18
# 11.926323        1         1         0         0       17
# 14.456149        1         1         0         0       16
# 14.686133        1         1         0         0       15
# 15.540360        1         1         0         0       14
# 16.328877        1         1         0         0       13
# 16.953120        1         1         0         0       12
# 18.135896        1         1         0         0       11
# 18.267316        1         1         0         0       10
# 18.563010        1         1         0         0        9
# 19.877205        1         1         0         0        8
# 20.008624        1         1         0         0        7
# 21.027126        1         1         0         0        6
# 23.162693        1         1         0         0        5
# 24.246904        1         1         0         0        4
# 25.363971        1         1         0         0        3
# 29.010863        1         1         0         0        2
# 30.226493        1         1         0         0        1
# Median survival time for Disease Control: 9.10 months
# Risk table for Disease Control:
#             removed  observed  censored  entrance  at_risk
# event_at
# 0.000000          0         0         0       252      252
# 0.065710          2         2         0         0      252
# 0.098565          1         1         0         0      250
# 0.131420          1         1         0         0      249
# 0.295694          1         1         0         0      248
# ...             ...       ...       ...       ...      ...
# 82.925727         1         1         0         0        5
# 97.546151         1         1         0         0        4
# 106.975503        1         1         0         0        3
# 107.172632        1         1         0         0        2
# 147.222736        1         1         0         0        1
#
# [216 rows x 5 columns]
# Median survival time for Palliative_care: 3.15 months
# Risk table for Palliative_care:
#            removed  observed  censored  entrance  at_risk
# event_at
# 0.000000         0         0         0       113      113
# 0.032855         1         1         0         0      113
# 0.328549         1         1         0         0      112
# 0.394259         1         1         0         0      111
# 0.492823         1         1         0         0      110
# ...            ...       ...       ...       ...      ...
# 13.109099        1         1         0         0        5
# 15.113247        1         1         0         0        4
# 15.343231        1         1         0         0        3
# 22.045627        1         1         0         0        2
# 22.932709        1         1         0         0        1
#
# [95 rows x 5 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\ANACONDA\lib\site-packages\lifelines\utils\__init__.py:966, in pass_for_numeric_dtypes_or_raise_array(x)
#     965 if v.size == 0:
# --> 966     raise ValueError("Empty array/Series passed in.")
#     967 return v
#
# ValueError: Empty array/Series passed in.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[120], line 18
#      16 for category in df["Treatment_final"].unique():
#      17     subset = df[df["Treatment_final"] == category]
# ---> 18     kmf.fit(subset["Time_overall_study"], event_observed=subset["Status"], label=category)
#      20     # Plot the Kaplan-Meier curve
#      21     kmf.plot(ci_show=False)
#
# File ~\ANACONDA\lib\site-packages\lifelines\utils\__init__.py:56, in CensoringType.right_censoring.<locals>.f(model, *args, **kwargs)
#      53 @wraps(function)
#      54 def f(model, *args, **kwargs):
#      55     cls.set_censoring_type(model, cls.RIGHT)
# ---> 56     return function(model, *args, **kwargs)
#
# File ~\ANACONDA\lib\site-packages\lifelines\fitters\kaplan_meier_fitter.py:127, in KaplanMeierFitter.fit(self, durations, event_observed, timeline, entry, label, alpha, ci_labels, weights, fit_options)
#      80 @CensoringType.right_censoring
#      81 def fit(
#      82     self,
#    (...)
#      91     fit_options=None,
#      92 ):  # pylint: disable=too-many-arguments,too-many-locals
#      93     """
#      94     Fit the model to a right-censored dataset
#      95
#    (...)
#     124
#     125     """
# --> 127     return self._fit(durations, event_observed, timeline, entry, label, alpha, ci_labels, weights)
#
# File ~\ANACONDA\lib\site-packages\lifelines\fitters\kaplan_meier_fitter.py:354, in KaplanMeierFitter._fit(self, durations, event_observed, timeline, entry, label, alpha, ci_labels, weights)
#     351 primary_estimate_name = "survival_function_"
#     352 secondary_estimate_name = "cumulative_density_"
# --> 354 (self.durations, self.event_observed, self.timeline, self.entry, self.event_table, self.weights) = _preprocess_inputs(
#     355     durations, event_observed, timeline, entry, weights
#     356 )
#     358 alpha = alpha if alpha else self.alpha
#     359 log_estimate, cumulative_sq_ = _additive_estimate(
#     360     self.event_table, self.timeline, self._additive_f, self._additive_var, is_left_censoring
#     361 )
#
# File ~\ANACONDA\lib\site-packages\lifelines\utils\__init__.py:906, in _preprocess_inputs(durations, event_observed, timeline, entry, weights)
#     901 """
#     902 Cleans and confirms input to what lifelines expects downstream
#     903 """
#     905 n = len(durations)
# --> 906 durations = np.asarray(pass_for_numeric_dtypes_or_raise_array(durations)).reshape((n,))
#     908 if weights is None:
#     909     weights = np.ones_like(durations)
#
# File ~\ANACONDA\lib\site-packages\lifelines\utils\__init__.py:970, in pass_for_numeric_dtypes_or_raise_array(x)
#     967     return v
#     969 except:
# --> 970     raise ValueError("Values must be numeric: no strings, datetimes, objects, etc.")
#
# ValueError: Values must be numeric: no strings, datetimes, objects, etc.

# %% [markdown]
# ### Survival Curve based on Surgery Type

# %%
data["Surgery_final"].value_counts()
# Out:
# No         249
# Simple     114
# Radical     43
# Partial      3
# Name: Surgery_final, dtype: int64

# %%
data["Surgery_final"].isnull().sum()
# Out:
# 16

# %% [markdown]
# **A total of 16 missing values in the "Surgery_final" feature**

# %% [markdown]
# **The missing data was assigned to a new category = "Missing_Data" category for seperate analysis**

# %%
# Assign missing values as "Missing_Data"
data['Surgery_final'] = data['Surgery_final'].fillna("Missing_Data")

# %%
data["Surgery_final"].value_counts()
# Out:
# No              249
# Simple          114
# Radical          43
# Missing_Data     16
# Partial           3
# Name: Surgery_final, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
from lifelines.utils import survival_table_from_events

# data
df = data[["Surgery_final", "Status", "Time_overall_study"]]

# Perform Kaplan-Meier survival analysis for each category
kmf = KaplanMeierFitter()

for category in df["Surgery_final"].unique():
    subset = df[df["Surgery_final"] == category]
    kmf.fit(subset["Time_overall_study"], event_observed=subset["Status"], label=category)

    # Plot the Kaplan-Meier curve
    kmf.plot(ci_show=False)

    # Calculate and print median survival time
    median_survival_time = kmf.median_survival_time_
    print(f"Median survival time for {category}: {median_survival_time:.2f} months")

    # Plot censored data points
    censored_data = subset[subset["Status"] == 0]
    plt.scatter(censored_data["Time_overall_study"], kmf.predict(censored_data["Time_overall_study"]),
            marker='x', color='black', s=50, label=f'Censored - {category}')
    
    # Calculate the risk table
    event_table = survival_table_from_events(subset["Time_overall_study"], subset["Status"])
    print(f"Risk table for {category}:\n{event_table}")
    
# Add title and labels to the plot
plt.title("Kaplan-Meier Survival Analysis w.r.t Surgery Type")
plt.xlabel("Time (months)")
plt.ylabel("Survival Probability")
plt.legend()

# Show the plot
plt.show()
# Out:
# Median survival time for Radical: 15.05 months
# Risk table for Radical:
#            removed  observed  censored  entrance  at_risk
# event_at
# 0.000000         0         0         0        43       43
# 0.919937         1         1         0         0       43
# 3.154069         1         1         0         0       42
# 3.942586         1         1         0         0       41
# 4.829668         1         1         0         0       40
# 5.289636         1         1         0         0       39
# 6.275283         1         1         0         0       38
# 6.932381         1         1         0         0       37
# 7.655188         1         1         0         0       36
# 7.950882         1         1         0         0       35
# 8.016592         1         1         0         0       34
# 9.133658         1         1         0         0       33
# 9.330787         1         1         0         0       32
# 9.692191         1         1         0         0       31
# 10.283579        2         2         0         0       30
# 10.349288        1         1         0         0       28
# 10.447853        1         1         0         0       27
# 10.973531        1         1         0         0       26
# 11.926323        1         1         0         0       25
# 14.456149        1         1         0         0       24
# 14.686133        1         1         0         0       23
# 15.047537        1         1         0         0       22
# 15.146102        1         1         0         0       21
# 15.540360        1         1         0         0       20
# 16.328877        1         1         0         0       19
# 16.460297        1         1         0         0       18
# 16.953120        1         1         0         0       17
# 18.135896        1         1         0         0       16
# 18.267316        1         1         0         0       15
# 18.563010        1         1         0         0       14
# 19.877205        1         1         0         0       13
# 20.008624        1         1         0         0       12
# 21.027126        1         1         0         0       11
# 23.162693        1         1         0         0       10
# 24.246904        1         1         0         0        9
# 25.363971        1         1         0         0        8
# 27.170989        1         1         0         0        7
# 27.598103        1         1         0         0        6
# 28.518039        1         1         0         0        5
# 29.010863        1         1         0         0        4
# 30.226493        1         1         0         0        3
# 38.177375        1         1         0         0        2
# 42.448510        1         1         0         0        1
# Median survival time for No: 5.29 months
# Risk table for No:
#            removed  observed  censored  entrance  at_risk
# event_at
# 0.000000         0         0         0       249      249
# 0.032855         1         1         0         0      249
# 0.065710         1         1         0         0      248
# 0.098565         1         1         0         0      247
# 0.131420         1         1         0         0      246
# ...            ...       ...       ...       ...      ...
# 27.992361        1         1         0         0        5
# 28.090926        1         1         0         0        4
# 28.715169        1         1         0         0        3
# 29.832235        1         1         0         0        2
# 38.505924        1         1         0         0        1
#
# [198 rows x 5 columns]
# Median survival time for Simple: 9.89 months
# Risk table for Simple:
#             removed  observed  censored  entrance  at_risk
# event_at
# 0.000000          0         0         0       114      114
# 0.065710          1         1         0         0      114
# 0.854227          1         1         0         0      113
# 1.314195          1         1         0         0      112
# 1.412760          2         2         0         0      111
# ...             ...       ...       ...       ...      ...
# 82.925727         1         1         0         0        5
# 97.546151         1         1         0         0        4
# 106.975503        1         1         0         0        3
# 107.172632        1         1         0         0        2
# 147.222736        1         1         0         0        1
#
# [106 rows x 5 columns]
# Median survival time for Partial: 21.36 months
# Risk table for Partial:
#            removed  observed  censored  entrance  at_risk
# event_at
# 0.000000         0         0         0         3        3
# 3.318343         1         1         0         0        3
# 21.355675        1         1         0         0        2
# 32.526335        1         1         0         0        1
# Median survival time for Missing_Data: 4.11 months
# Risk table for Missing_Data:
#            removed  observed  censored  entrance  at_risk
# event_at
# 0.000000         1         1         0        16       16
# 0.394259         1         1         0         0       15
# 1.051356         1         1         0         0       14
# 1.511325         1         1         0         0       13
# 2.956940         1         1         0         0       12
# 3.581182         2         2         0         0       11
# 4.106861         1         1         0         0        9
# 6.505267         1         1         0         0        8
# 6.735251         1         1         0         0        7
# 8.837964         1         1         0         0        6
# 11.893468        1         1         0         0        5
# 11.959178        1         1         0         0        4
# 12.419146        1         1         0         0        3
# 25.495390        1         1         0         0        2
# 30.357913        1         1         0         0        1

# %% [markdown]
# **Since there is only one black cross and that too on the "green" curve, it signifies that 1 observation that is censored, belongs to the " simple cholecystectomy" category of the "Tumour_stage_final" feature.**
#
# **Median survival time for No Surgery: 5.29 months**
#
# **Median survival time for Simple: 9.89 months**
#
# **Median survival time for Radical: 15.05 months**
#
# **Median survival time for Partial: 21.36 months**
#
# **Median survival time for Missing_Data: 4.11 months**

# %%
# Create a cross-tabulation table
cross_tab = pd.crosstab(data['Tumour_stage_final'], data['Surgery_final'])

# Display the cross-tabulation table
print(cross_tab)
# Out:
# Surgery_final       Missing_Data   No  Partial  Radical  Simple
# Tumour_stage_final
# Missing_Data                  15   19        0        2       5
# Not known                      0   12        1        3      22
# Stage II                       0    0        0        5       9
# Stage III                      0   27        1       18       9
# Stage IV                       1  191        1       15      69

# %%
data["Tumour_stage_final"].value_counts()
# Out:
# Stage IV        277
# Stage III        55
# Missing_Data     41
# Not known        38
# Stage II         14
# Name: Tumour_stage_final, dtype: int64

# %%
data["Status"].value_counts()
# Out:
# True     424
# False      1
# Name: Status, dtype: int64

# %%
df = filtered_data[filtered_data["Status"]=="No"]

# %%
df["Surgery_final"]
# Out:
# 47    Simple
# Name: Surgery_final, dtype: object

# %% [markdown]
# **Surgery type for 1 censored observation in our data = "simple". Verified.**

# %%
########## BASED ON TREATMENT ###########

# %%
df["Treatment_final"].value_counts()
# Out:
# Disease Control    1
# Name: Treatment_final, dtype: int64

# %%
import pandas as pd
from lifelines import KaplanMeierFitter
import matplotlib.pyplot as plt

# Assuming "data" is your DataFrame

# Assuming "Tumour_stage_final" and "Surgery_final" are categorical columns
# Assuming "Status" is the survival status (1 for event, 0 for censored)
# Assuming "Time_overall_study" is the survival time

# Convert categorical variables to strings
data['Tumour_stage_final'] = data['Tumour_stage_final'].astype(str)
data['Surgery_final'] = data['Surgery_final'].astype(str)

# Create a Kaplan-Meier estimator for each combination of Tumour_stage_final and Surgery_final
kmf = KaplanMeierFitter()

# Create a figure and axis
fig, ax = plt.subplots()

# Iterate over unique combinations of Tumour_stage_final and Surgery_final
for (tumour_stage, surgery), grouped_data in data.groupby(['Tumour_stage_final', 'Surgery_final']):
    kmf.fit(grouped_data['Time_overall_study'], event_observed=grouped_data['Status'], label=f"{tumour_stage}_{surgery}")
    kmf.plot_survival_function(ax=ax)

# Calculate overall survival rate
overall_survival_rate = 1 - kmf.survival_function_.iloc[-1].values[0]
print(f"Overall Survival Rate: {overall_survival_rate:.2%}")

# Calculate median survival time
median_survival_time = kmf.median_survival_time_
print(f"Median Survival Time: {median_survival_time} units (e.g., days)")

# Show the plot
plt.legend(title='Groups')
plt.show()
# Out:
# Overall Survival Rate: 100.00%
# Median Survival Time: 9.330787079816835 units (e.g., days)

# %%
from lifelines import KaplanMeierFitter
import pandas as pd
from tqdm.auto import tqdm

# Assuming 'data' is already loaded in the environment
# Step 1: Combine the 'Tumour_stage_final' and 'Surgery_final' into a single feature
# Step 2: Fit the Kaplan-Meier estimator for each group

# Create a new feature that combines Tumour_stage and Surgery_final
# This will be used to group the survival data
combined_feature = data['Tumour_stage_final'].astype(str) + '_' + data['Surgery_final'].astype(str)
data['Combined'] = combined_feature

# Initialize KaplanMeierFitter
kmf = KaplanMeierFitter()

# Dictionary to store survival analysis results
survival_analysis_results = {}

# Perform survival analysis for each group
for group in tqdm(data['Combined'].unique(), desc='Survival Analysis Progress'):
    group_data = data[data['Combined'] == group]
    T = group_data['Time_overall_study'] # Time to event or censor
    E = group_data['Status'] # Event occurred or censored
    kmf.fit(T, E, label=group)
    survival_analysis_results[group] = {
        'Survival_Function_': kmf.survival_function_.to_dict(),
        'Median_Survival_Time': kmf.median_survival_time_
    }

# Display the results for the first group as an example
first_group = list(survival_analysis_results.keys())[0]
survival_analysis_results[first_group]
# Out:
# Survival Analysis Progress:   0%|          | 0/19 [00:00<?, ?it/s]
# {'Survival_Function_': {'Stage IV_Radical': {0.0: 1.0,
#    3.942586090063451: 0.9333333333333331,
#    4.829667960327727: 0.8666666666666667,
#    6.27528286001766: 0.8,
#    7.655187991539868: 0.7333333333333334,
#    8.01659171646235: 0.6666666666666669,
#    14.456148996899321: 0.6000000000000001,
#    14.686133185486355: 0.5333333333333332,
#    15.146101562660425: 0.4666666666666666,
#    16.95312018727284: 0.39999999999999997,
#    20.008624407072013: 0.3333333333333333,
#    24.246904453890224: 0.26666666666666666,
#    27.598102630444156: 0.2,
#    29.010862646050228: 0.13333333333333333,
#    38.177375305447754: 0.06666666666666667,
#    42.448510236349826: 0.0}},
#  'Median_Survival_Time': 15.146101562660425}

# %%
from lifelines import KaplanMeierFitter
import pandas as pd
from tqdm.auto import tqdm

# Assuming 'data' is already loaded in the environment
# Step 1: Combine the 'Tumour_stage_final' and 'Surgery_final' into a single feature
# Step 2: Fit the Kaplan-Meier estimator for each group

# Create a new feature that combines Tumour_stage and Surgery_final
# This will be used to group the survival data
combined_feature = data['Tumour_stage_final'].astype(str) + '_' + data['Surgery_final'].astype(str)
data['Combined'] = combined_feature

# Initialize KaplanMeierFitter
kmf = KaplanMeierFitter()

# Dictionary to store survival analysis results
survival_analysis_results = {}

# Perform survival analysis for each group
for group in tqdm(data['Combined'].unique(), desc='Survival Analysis Progress'):
    group_data = data[data['Combined'] == group]
    T = group_data['Time_overall_study'] # Time to event or censor
    E = group_data['Status'] # Event occurred or censored
    kmf.fit(T, E, label=group)
    survival_analysis_results[group] = {
        'Survival_Function_': kmf.survival_function_.to_dict(),
        'Median_Survival_Time': kmf.median_survival_time_
    }

# Display the results for the first group as an example
first_group = list(survival_analysis_results.keys())[2]
survival_analysis_results[first_group]
# Out:
# Survival Analysis Progress:   0%|          | 0/19 [00:00<?, ?it/s]
# {'Survival_Function_': {'Stage II_Simple': {0.0: 1.0,
#    1.8727283927801393: 0.8888888888888886,
#    2.069857697283312: 0.7777777777777776,
#    9.790755456990903: 0.6666666666666665,
#    13.20766340171256: 0.5555555555555554,
#    13.339082938048008: 0.44444444444444436,
#    17.248814144027598: 0.3333333333333333,
#    20.862851393252427: 0.2222222222222222,
#    23.852645844883877: 0.11111111111111109,
#    38.144520421363886: 0.0}},
#  'Median_Survival_Time': 13.339082938048008}

# %%
from lifelines import KaplanMeierFitter
import pandas as pd

# Load your data into a DataFrame named 'data'
# data = pd.read_csv('your_data.csv')

# Combine 'Tumour_stage_final' and 'Surgery_final' into a single feature
data['Combined'] = data['Tumour_stage_final'].astype(str) + '_' + data['Surgery_final'].astype(str)

# Initialize KaplanMeierFitter
kmf = KaplanMeierFitter()

# Dictionary to store 2-year survival analysis results
two_year_survival_results = {}

# Perform survival analysis for each group
for group in data['Combined'].unique():
    group_data = data[data['Combined'] == group]
    T = group_data['Time_overall_study']  # Time to event or censor
    E = group_data['Status']  # Event occurred or censored
    kmf.fit(T, E, timeline=range(0, 731), label=group)  # Fit up to 730 days (2 years)
    survival_probability_at_2_years = kmf.survival_function_at_times(times=730).get(group)
    median_survival_time_up_to_2_years = kmf.median_survival_time_
    
    # Store results
    two_year_survival_results[group] = {
        '2_Year_Survival_Percentage': survival_probability_at_2_years,
        '2_Year_Median_Survival_Time': median_survival_time_up_to_2_years
    }

# Convert results to a DataFrame for better visualization
two_year_survival_df = pd.DataFrame(two_year_survival_results).T
two_year_survival_df
# Out:
#                            2_Year_Survival_Percentage  \
# Stage IV_Radical                                  NaN
# Stage IV_No                                       NaN
# Stage II_Simple                                   NaN
# Not known_No                                      NaN
# Not known_Radical                                 NaN
# Stage III_Radical                                 NaN
# Stage IV_Simple                                   NaN
# Not known_Simple                                  NaN
# Stage II_Radical                                  NaN
# Stage III_Simple                                  NaN
# Stage III_No                                      NaN
# Stage IV_Partial                                  NaN
# Missing_Data_No                                   NaN
# Missing_Data_Simple                               NaN
# Missing_Data_Missing_Data                         NaN
# Missing_Data_Radical                              NaN
# Stage IV_Missing_Data                             NaN
# Not known_Partial                                 NaN
# Stage III_Partial                                 NaN
#
#                            2_Year_Median_Survival_Time
# Stage IV_Radical                                  16.0
# Stage IV_No                                        6.0
# Stage II_Simple                                   14.0
# Not known_No                                       6.0
# Not known_Radical                                  8.0
# Stage III_Radical                                 16.0
# Stage IV_Simple                                   10.0
# Not known_Simple                                  13.0
# Stage II_Radical                                  12.0
# Stage III_Simple                                   8.0
# Stage III_No                                       8.0
# Stage IV_Partial                                  33.0
# Missing_Data_No                                    3.0
# Missing_Data_Simple                                7.0
# Missing_Data_Missing_Data                          5.0
# Missing_Data_Radical                              19.0
# Stage IV_Missing_Data                             12.0
# Not known_Partial                                 22.0
# Stage III_Partial                                  4.0

# %%
import pandas as pd

# Assuming "data" is your DataFrame

# Filter the data based on "Surgery_final" equal to "Radical"
filtered_data1 = data[(data['Surgery_final'] == 'Radical') & (data['Tumour_stage_final']=="Stage II") ]

# Keep only the specified columns
filtered_data1 = filtered_data1[['Tumour_stage_final', 'Time_overall_study', 'Status']]

# Display the resulting DataFrame
print(filtered_data1)
# Out:
#     Tumour_stage_final  Time_overall_study  Status
# 46            Stage II            9.330787    True
# 116           Stage II            0.919937    True
# 145           Stage II           27.170989    True
# 359           Stage II           15.540360    True
# 656           Stage II           11.926323    True

# %%
filtered_data1["Time_overall_study"].mean()
# Out:
# 12.977679213125526

# %%
import pandas as pd
import matplotlib.pyplot as plt
from lifelines.utils import survival_table_from_events

# data
df = filtered_data1

# Perform Kaplan-Meier survival analysis for each category
kmf = KaplanMeierFitter()

for category in df["Tumour_stage_final"].unique():
    subset = df[df["Tumour_stage_final"] == category]
    kmf.fit(subset["Time_overall_study"], event_observed=subset["Status"], label=category)

    # Plot the Kaplan-Meier curve
    kmf.plot(ci_show=False)

    # Calculate and print median survival time
    median_survival_time = kmf.median_survival_time_
    print(f"Median survival time for {category}: {median_survival_time:.2f} months")

    # Plot censored data points
    censored_data = subset[subset["Status"] == 0]
    plt.scatter(censored_data["Time_overall_study"], kmf.predict(censored_data["Time_overall_study"]),
            marker='x', color='black', s=50, label=f'Censored - {category}')
    
    # Calculate the risk table
    event_table = survival_table_from_events(subset["Time_overall_study"], subset["Status"])
    print(f"Risk table for {category}:\n{event_table}")
    
# Add title and labels to the plot
plt.title("Kaplan-Meier Survival Analysis w.r.t Surgery Type")
plt.xlabel("Time (months)")
plt.ylabel("Survival Probability")
plt.legend()

# Show the plot
plt.show()
# Out:
# Median survival time for Stage II: 11.93 months
# Risk table for Stage II:
#            removed  observed  censored  entrance  at_risk
# event_at
# 0.000000         0         0         0         5        5
# 0.919937         1         1         0         0        5
# 9.330787         1         1         0         0        4
# 11.926323        1         1         0         0        3
# 15.540360        1         1         0         0        2
# 27.170989        1         1         0         0        1

# %%
df = data.copy()

# %%
# Replace "Simple" and "Partial" with "Simple + Partial"
df['Surgery_final'] = df['Surgery_final'].replace({'Simple': 'Simple + Partial', 'Partial': 'Simple + Partial'})

# Display the resulting DataFrame
print(df["Surgery_final"].value_counts())
# Out:
# No                  249
# Simple + Partial    117
# Radical              43
# Missing_Data         16
# Name: Surgery_final, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
from lifelines.utils import survival_table_from_events

# data
df = df

# Perform Kaplan-Meier survival analysis for each category
kmf = KaplanMeierFitter()

for category in df["Surgery_final"].unique():
    subset = df[df["Surgery_final"] == category]
    kmf.fit(subset["Time_overall_study"], event_observed=subset["Status"], label=category)

    # Plot the Kaplan-Meier curve
    kmf.plot(ci_show=False)

    # Calculate and print median survival time
    median_survival_time = kmf.median_survival_time_
    print(f"Median survival time for {category}: {median_survival_time:.2f} months")

    # Plot censored data points
    censored_data = subset[subset["Status"] == 0]
    plt.scatter(censored_data["Time_overall_study"], kmf.predict(censored_data["Time_overall_study"]),
            marker='x', color='black', s=50, label=f'Censored - {category}')
    
    # Calculate the risk table
    event_table = survival_table_from_events(subset["Time_overall_study"], subset["Status"])
    print(f"Risk table for {category}:\n{event_table}")
    
# Add title and labels to the plot
plt.title("Kaplan-Meier Survival Analysis w.r.t Surgery Type")
plt.xlabel("Time (months)")
plt.ylabel("Survival Probability")
plt.legend()

# Show the plot
plt.show()
# Out:
# Median survival time for Radical: 15.05 months
# Risk table for Radical:
#            removed  observed  censored  entrance  at_risk
# event_at
# 0.000000         0         0         0        43       43
# 0.919937         1         1         0         0       43
# 3.154069         1         1         0         0       42
# 3.942586         1         1         0         0       41
# 4.829668         1         1         0         0       40
# 5.289636         1         1         0         0       39
# 6.275283         1         1         0         0       38
# 6.932381         1         1         0         0       37
# 7.655188         1         1         0         0       36
# 7.950882         1         1         0         0       35
# 8.016592         1         1         0         0       34
# 9.133658         1         1         0         0       33
# 9.330787         1         1         0         0       32
# 9.692191         1         1         0         0       31
# 10.283579        2         2         0         0       30
# 10.349288        1         1         0         0       28
# 10.447853        1         1         0         0       27
# 10.973531        1         1         0         0       26
# 11.926323        1         1         0         0       25
# 14.456149        1         1         0         0       24
# 14.686133        1         1         0         0       23
# 15.047537        1         1         0         0       22
# 15.146102        1         1         0         0       21
# 15.540360        1         1         0         0       20
# 16.328877        1         1         0         0       19
# 16.460297        1         1         0         0       18
# 16.953120        1         1         0         0       17
# 18.135896        1         1         0         0       16
# 18.267316        1         1         0         0       15
# 18.563010        1         1         0         0       14
# 19.877205        1         1         0         0       13
# 20.008624        1         1         0         0       12
# 21.027126        1         1         0         0       11
# 23.162693        1         1         0         0       10
# 24.246904        1         1         0         0        9
# 25.363971        1         1         0         0        8
# 27.170989        1         1         0         0        7
# 27.598103        1         1         0         0        6
# 28.518039        1         1         0         0        5
# 29.010863        1         1         0         0        4
# 30.226493        1         1         0         0        3
# 38.177375        1         1         0         0        2
# 42.448510        1         1         0         0        1
# Median survival time for No: 5.29 months
# Risk table for No:
#            removed  observed  censored  entrance  at_risk
# event_at
# 0.000000         0         0         0       249      249
# 0.032855         1         1         0         0      249
# 0.065710         1         1         0         0      248
# 0.098565         1         1         0         0      247
# 0.131420         1         1         0         0      246
# ...            ...       ...       ...       ...      ...
# 27.992361        1         1         0         0        5
# 28.090926        1         1         0         0        4
# 28.715169        1         1         0         0        3
# 29.832235        1         1         0         0        2
# 38.505924        1         1         0         0        1
#
# [198 rows x 5 columns]
# Median survival time for Simple + Partial: 10.09 months
# Risk table for Simple + Partial:
#             removed  observed  censored  entrance  at_risk
# event_at
# 0.000000          0         0         0       117      117
# 0.065710          1         1         0         0      117
# 0.854227          1         1         0         0      116
# 1.314195          1         1         0         0      115
# 1.412760          2         2         0         0      114
# ...             ...       ...       ...       ...      ...
# 82.925727         1         1         0         0        5
# 97.546151         1         1         0         0        4
# 106.975503        1         1         0         0        3
# 107.172632        1         1         0         0        2
# 147.222736        1         1         0         0        1
#
# [109 rows x 5 columns]
# Median survival time for Missing_Data: 4.11 months
# Risk table for Missing_Data:
#            removed  observed  censored  entrance  at_risk
# event_at
# 0.000000         1         1         0        16       16
# 0.394259         1         1         0         0       15
# 1.051356         1         1         0         0       14
# 1.511325         1         1         0         0       13
# 2.956940         1         1         0         0       12
# 3.581182         2         2         0         0       11
# 4.106861         1         1         0         0        9
# 6.505267         1         1         0         0        8
# 6.735251         1         1         0         0        7
# 8.837964         1         1         0         0        6
# 11.893468        1         1         0         0        5
# 11.959178        1         1         0         0        4
# 12.419146        1         1         0         0        3
# 25.495390        1         1         0         0        2
# 30.357913        1         1         0         0        1

# %%
category_list = ['Tumour_stage_final', 'Surgery_final', 'Treatment_final', 'Cancer_presentation_final']

def plotUnivariateAnalysis(data_frame, category_list, rows, cols, figsize):
    fig, axes = plt.subplots(rows, cols, figsize=figsize)
    axes = axes.flatten()
    
    for i, category in enumerate(category_list):
        ax = axes[i]
        counts = data_frame[category].value_counts()
        missing_count = data_frame[category].isnull().sum()
        total_count = len(data_frame)
        
        counts.plot(kind='bar', ax=ax)
        
        ax.set_title(f'{category} Distribution')
        ax.set_xlabel(category)
        ax.set_ylabel('Frequency')
        
        # Calculate and display percentage text on the bars
        total_valid_count = total_count - missing_count
        for rect in ax.patches:
            height = rect.get_height()
            ax.annotate(f'{height / total_valid_count:.2%}', 
                        xy=(rect.get_x() + rect.get_width() / 2, height), 
                        xytext=(0, 3),  # 3 points vertical offset
                        textcoords="offset points", 
                        ha='center', va='bottom')
        
        # Display percentage of missing values above the plot
        ax.annotate(f"Missing: {missing_count}/{total_count} ({missing_count / total_count:.2%})", 
                    xy=(0.5, 0.95), 
                    xycoords='axes fraction', 
                    ha='center', fontsize=10, color='red')
    
    # Hide any unused subplots
    for i in range(len(category_list), rows * cols):
        fig.delaxes(axes[i])
    
    plt.tight_layout()
    plt.show()

# %%
# PLOTS FOR THE WHOLE DATA
# Call the function to create the grid of plots
plotUnivariateAnalysis(data_frame=df, 
                       category_list=category_list, 
                       rows=2, 
                       cols=3, 
                       figsize=(18, 10))

# %%
data.columns
# Out:
# Index(['Thyroidism', 'Diabetes', 'HTN', 'Family_cancer_history', 'ECOG_final',
#        'Gall_stone_final', 'Pathology', 'Cancer_presentation_final',
#        'Tumour_stage_final', 'Mets_site_final', 'Surgery_final',
#        'Treatment_final', 'Status', 'Date_event', 'Date_diagnosis', 'AGE',
#        'BMI_DETAILS', 'BILIRUBIN TOTAL', 'AST - SGOT', 'ALT - SGPT',
#        'ALK PHOS [ALP]', 'GAMMA GT', 'ALBUMIN', 'Time_overall_study',
#        'Combined'],
#       dtype='object')

# %%
data["Surgery_final"].value_counts()
# Out:
# No              249
# Simple          114
# Radical          43
# Missing_Data     16
# Partial           3
# Name: Surgery_final, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming "data" is your DataFrame

# Create a new DataFrame with the percentage distribution
grouped_data = df.groupby(['Tumour_stage_final', 'Surgery_final']).size().unstack()

# Calculate the percentage distribution
percentage_distribution = grouped_data.div(grouped_data.sum(axis=1), axis=0) * 100

# Plot the grouped bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=percentage_distribution.index, y=percentage_distribution['No'], label='No', color='blue')
sns.barplot(x=percentage_distribution.index, y=percentage_distribution['Simple + Partial'], label='Simple + Partial', color='red')
sns.barplot(x=percentage_distribution.index, y=percentage_distribution['Radical'], label='Radical', color='green')
sns.barplot(x=percentage_distribution.index, y=percentage_distribution['Missing_Data'], label='Missing_Data', color='yellow')
#sns.barplot(x=percentage_distribution.index, y=percentage_distribution['Partial'], label='Partial', color='orange')
# Add more bar plots for other surgery types as needed

plt.title('% Distribution of Patients by Tumour Stage and Surgery Type')
plt.xlabel('Tumour Stage')
plt.ylabel('% of patients')
plt.legend(title='Surgery Type', loc='upper left')
plt.show()

# %%
# Create a new DataFrame with the percentage distribution
grouped_data = df.groupby(['Tumour_stage_final', 'Surgery_final']).size().unstack()
grouped_data
# Out:
# Surgery_final       Missing_Data     No  Radical  Simple + Partial
# Tumour_stage_final
# Missing_Data                15.0   19.0      2.0               5.0
# Not known                    NaN   12.0      3.0              23.0
# Stage II                     NaN    NaN      5.0               9.0
# Stage III                    NaN   27.0     18.0              10.0
# Stage IV                     1.0  191.0     15.0              70.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming "data" is your DataFrame

# Create a new DataFrame with the percentage distribution
grouped_data = df.groupby(['Tumour_stage_final', 'Surgery_final']).size().unstack()

# Calculate the percentage distribution
percentage_distribution = grouped_data.div(grouped_data.sum(axis=1), axis=0) * 100

# Define the desired order for the x-axis
desired_order = ["Stage II", "Stage III", "Stage IV", "Not known", "Missing_Data"]

# Plot the grouped bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=percentage_distribution.index, y=percentage_distribution['No'], order=desired_order, label='No', color='blue')
sns.barplot(x=percentage_distribution.index, y=percentage_distribution['Simple + Partial'], order=desired_order, label='Simple + Partial', color='red')
sns.barplot(x=percentage_distribution.index, y=percentage_distribution['Radical'], order=desired_order, label='Radical', color='green')
sns.barplot(x=percentage_distribution.index, y=percentage_distribution['Missing_Data'], order=desired_order, label='Missing_Data', color='yellow')
#sns.barplot(x=percentage_distribution.index, y=percentage_distribution['Partial'], order=desired_order, label='Partial', color='orange')
# Add more bar plots for other surgery types as needed

plt.title('% Distribution of Patients by Tumour Stage and Surgery Type')
plt.xlabel('Tumour Stage')
plt.ylabel('% of Patients')
plt.legend(title='Surgery Type', loc='upper right')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from lifelines.utils import survival_table_from_events

# data
df = df[["Surgery_final", "Status", "Time_overall_study"]]

# Perform Kaplan-Meier survival analysis for each category
kmf = KaplanMeierFitter()

for category in df["Surgery_final"].unique():
    subset = df[df["Surgery_final"] == category]
    kmf.fit(subset["Time_overall_study"], event_observed=subset["Status"], label=category)

    # Plot the Kaplan-Meier curve
    kmf.plot(ci_show=False)

    # Calculate and print median survival time
    median_survival_time = kmf.median_survival_time_
    print(f"Median survival time for {category}: {median_survival_time:.2f} months")

    # Plot censored data points
    censored_data = subset[subset["Status"] == 0]
    plt.scatter(censored_data["Time_overall_study"], kmf.predict(censored_data["Time_overall_study"]),
            marker='x', color='black', s=50, label=f'Censored - {category}')
    
    # Calculate the risk table
    event_table = survival_table_from_events(subset["Time_overall_study"], subset["Status"])
    print(f"Risk table for {category}:\n{event_table}")
    
# Add title and labels to the plot
plt.title("Kaplan-Meier Survival Analysis w.r.t Surgery Type")
plt.xlabel("Time (months)")
plt.ylabel("Survival Probability")
plt.legend()

# Show the plot
plt.show()
# Out:
# Median survival time for Radical: 15.05 months
# Risk table for Radical:
#            removed  observed  censored  entrance  at_risk
# event_at
# 0.000000         0         0         0        43       43
# 0.919937         1         1         0         0       43
# 3.154069         1         1         0         0       42
# 3.942586         1         1         0         0       41
# 4.829668         1         1         0         0       40
# 5.289636         1         1         0         0       39
# 6.275283         1         1         0         0       38
# 6.932381         1         1         0         0       37
# 7.655188         1         1         0         0       36
# 7.950882         1         1         0         0       35
# 8.016592         1         1         0         0       34
# 9.133658         1         1         0         0       33
# 9.330787         1         1         0         0       32
# 9.692191         1         1         0         0       31
# 10.283579        2         2         0         0       30
# 10.349288        1         1         0         0       28
# 10.447853        1         1         0         0       27
# 10.973531        1         1         0         0       26
# 11.926323        1         1         0         0       25
# 14.456149        1         1         0         0       24
# 14.686133        1         1         0         0       23
# 15.047537        1         1         0         0       22
# 15.146102        1         1         0         0       21
# 15.540360        1         1         0         0       20
# 16.328877        1         1         0         0       19
# 16.460297        1         1         0         0       18
# 16.953120        1         1         0         0       17
# 18.135896        1         1         0         0       16
# 18.267316        1         1         0         0       15
# 18.563010        1         1         0         0       14
# 19.877205        1         1         0         0       13
# 20.008624        1         1         0         0       12
# 21.027126        1         1         0         0       11
# 23.162693        1         1         0         0       10
# 24.246904        1         1         0         0        9
# 25.363971        1         1         0         0        8
# 27.170989        1         1         0         0        7
# 27.598103        1         1         0         0        6
# 28.518039        1         1         0         0        5
# 29.010863        1         1         0         0        4
# 30.226493        1         1         0         0        3
# 38.177375        1         1         0         0        2
# 42.448510        1         1         0         0        1
# Median survival time for No: 5.29 months
# Risk table for No:
#            removed  observed  censored  entrance  at_risk
# event_at
# 0.000000         0         0         0       249      249
# 0.032855         1         1         0         0      249
# 0.065710         1         1         0         0      248
# 0.098565         1         1         0         0      247
# 0.131420         1         1         0         0      246
# ...            ...       ...       ...       ...      ...
# 27.992361        1         1         0         0        5
# 28.090926        1         1         0         0        4
# 28.715169        1         1         0         0        3
# 29.832235        1         1         0         0        2
# 38.505924        1         1         0         0        1
#
# [198 rows x 5 columns]
# Median survival time for Simple + Partial: 10.09 months
# Risk table for Simple + Partial:
#             removed  observed  censored  entrance  at_risk
# event_at
# 0.000000          0         0         0       117      117
# 0.065710          1         1         0         0      117
# 0.854227          1         1         0         0      116
# 1.314195          1         1         0         0      115
# 1.412760          2         2         0         0      114
# ...             ...       ...       ...       ...      ...
# 82.925727         1         1         0         0        5
# 97.546151         1         1         0         0        4
# 106.975503        1         1         0         0        3
# 107.172632        1         1         0         0        2
# 147.222736        1         1         0         0        1
#
# [109 rows x 5 columns]
# Median survival time for Missing_Data: 4.11 months
# Risk table for Missing_Data:
#            removed  observed  censored  entrance  at_risk
# event_at
# 0.000000         1         1         0        16       16
# 0.394259         1         1         0         0       15
# 1.051356         1         1         0         0       14
# 1.511325         1         1         0         0       13
# 2.956940         1         1         0         0       12
# 3.581182         2         2         0         0       11
# 4.106861         1         1         0         0        9
# 6.505267         1         1         0         0        8
# 6.735251         1         1         0         0        7
# 8.837964         1         1         0         0        6
# 11.893468        1         1         0         0        5
# 11.959178        1         1         0         0        4
# 12.419146        1         1         0         0        3
# 25.495390        1         1         0         0        2
# 30.357913        1         1         0         0        1

# %%
import pandas as pd
import matplotlib.pyplot as plt
from lifelines.utils import survival_table_from_events

# data
df = data[["Treatment_final", "Status", "Time_overall_study"]]

# Perform Kaplan-Meier survival analysis for each category
kmf = KaplanMeierFitter()

for category in df["Treatment_final"].unique():
    subset = df[df["Treatment_final"] == category]
    kmf.fit(subset["Time_overall_study"], event_observed=subset["Status"], label=category)

    # Plot the Kaplan-Meier curve
    kmf.plot(ci_show=False)

    # Calculate and print median survival time
    median_survival_time = kmf.median_survival_time_
    print(f"Median survival time for {category}: {median_survival_time:.2f} months")

    # Plot censored data points
    censored_data = subset[subset["Status"] == 0]
    plt.scatter(censored_data["Time_overall_study"], kmf.predict(censored_data["Time_overall_study"]),
            marker='x', color='black', s=50, label=f'Censored - {category}')
    
    # Calculate the risk table
    event_table = survival_table_from_events(subset["Time_overall_study"], subset["Status"])
    print(f"Risk table for {category}:\n{event_table}")
    
# Add title and labels to the plot
plt.title("Kaplan-Meier Survival Analysis w.r.t Treatment Type")
plt.xlabel("Time (months)")
plt.ylabel("Survival Probability")
plt.legend()

# Show the plot
plt.show()
# Out:
# Median survival time for Curative: 14.69 months
# Risk table for Curative:
#            removed  observed  censored  entrance  at_risk
# event_at
# 0.000000         0         0         0        29       29
# 0.919937         1         1         0         0       29
# 4.829668         1         1         0         0       28
# 6.275283         1         1         0         0       27
# 6.932381         1         1         0         0       26
# 7.655188         1         1         0         0       25
# 8.016592         1         1         0         0       24
# 9.133658         1         1         0         0       23
# 9.692191         1         1         0         0       22
# 10.283579        1         1         0         0       21
# 10.349288        1         1         0         0       20
# 10.447853        1         1         0         0       19
# 10.973531        1         1         0         0       18
# 11.926323        1         1         0         0       17
# 14.456149        1         1         0         0       16
# 14.686133        1         1         0         0       15
# 15.540360        1         1         0         0       14
# 16.328877        1         1         0         0       13
# 16.953120        1         1         0         0       12
# 18.135896        1         1         0         0       11
# 18.267316        1         1         0         0       10
# 18.563010        1         1         0         0        9
# 19.877205        1         1         0         0        8
# 20.008624        1         1         0         0        7
# 21.027126        1         1         0         0        6
# 23.162693        1         1         0         0        5
# 24.246904        1         1         0         0        4
# 25.363971        1         1         0         0        3
# 29.010863        1         1         0         0        2
# 30.226493        1         1         0         0        1
# Median survival time for Disease Control: 9.10 months
# Risk table for Disease Control:
#             removed  observed  censored  entrance  at_risk
# event_at
# 0.000000          0         0         0       252      252
# 0.065710          2         2         0         0      252
# 0.098565          1         1         0         0      250
# 0.131420          1         1         0         0      249
# 0.295694          1         1         0         0      248
# ...             ...       ...       ...       ...      ...
# 82.925727         1         1         0         0        5
# 97.546151         1         1         0         0        4
# 106.975503        1         1         0         0        3
# 107.172632        1         1         0         0        2
# 147.222736        1         1         0         0        1
#
# [216 rows x 5 columns]
# Median survival time for Palliative_care: 3.15 months
# Risk table for Palliative_care:
#            removed  observed  censored  entrance  at_risk
# event_at
# 0.000000         0         0         0       113      113
# 0.032855         1         1         0         0      113
# 0.328549         1         1         0         0      112
# 0.394259         1         1         0         0      111
# 0.492823         1         1         0         0      110
# ...            ...       ...       ...       ...      ...
# 13.109099        1         1         0         0        5
# 15.113247        1         1         0         0        4
# 15.343231        1         1         0         0        3
# 22.045627        1         1         0         0        2
# 22.932709        1         1         0         0        1
#
# [95 rows x 5 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\ANACONDA\lib\site-packages\lifelines\utils\__init__.py:966, in pass_for_numeric_dtypes_or_raise_array(x)
#     965 if v.size == 0:
# --> 966     raise ValueError("Empty array/Series passed in.")
#     967 return v
#
# ValueError: Empty array/Series passed in.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[157], line 13
#      11 for category in df["Treatment_final"].unique():
#      12     subset = df[df["Treatment_final"] == category]
# ---> 13     kmf.fit(subset["Time_overall_study"], event_observed=subset["Status"], label=category)
#      15     # Plot the Kaplan-Meier curve
#      16     kmf.plot(ci_show=False)
#
# File ~\ANACONDA\lib\site-packages\lifelines\utils\__init__.py:56, in CensoringType.right_censoring.<locals>.f(model, *args, **kwargs)
#      53 @wraps(function)
#      54 def f(model, *args, **kwargs):
#      55     cls.set_censoring_type(model, cls.RIGHT)
# ---> 56     return function(model, *args, **kwargs)
#
# File ~\ANACONDA\lib\site-packages\lifelines\fitters\kaplan_meier_fitter.py:127, in KaplanMeierFitter.fit(self, durations, event_observed, timeline, entry, label, alpha, ci_labels, weights, fit_options)
#      80 @CensoringType.right_censoring
#      81 def fit(
#      82     self,
#    (...)
#      91     fit_options=None,
#      92 ):  # pylint: disable=too-many-arguments,too-many-locals
#      93     """
#      94     Fit the model to a right-censored dataset
#      95
#    (...)
#     124
#     125     """
# --> 127     return self._fit(durations, event_observed, timeline, entry, label, alpha, ci_labels, weights)
#
# File ~\ANACONDA\lib\site-packages\lifelines\fitters\kaplan_meier_fitter.py:354, in KaplanMeierFitter._fit(self, durations, event_observed, timeline, entry, label, alpha, ci_labels, weights)
#     351 primary_estimate_name = "survival_function_"
#     352 secondary_estimate_name = "cumulative_density_"
# --> 354 (self.durations, self.event_observed, self.timeline, self.entry, self.event_table, self.weights) = _preprocess_inputs(
#     355     durations, event_observed, timeline, entry, weights
#     356 )
#     358 alpha = alpha if alpha else self.alpha
#     359 log_estimate, cumulative_sq_ = _additive_estimate(
#     360     self.event_table, self.timeline, self._additive_f, self._additive_var, is_left_censoring
#     361 )
#
# File ~\ANACONDA\lib\site-packages\lifelines\utils\__init__.py:906, in _preprocess_inputs(durations, event_observed, timeline, entry, weights)
#     901 """
#     902 Cleans and confirms input to what lifelines expects downstream
#     903 """
#     905 n = len(durations)
# --> 906 durations = np.asarray(pass_for_numeric_dtypes_or_raise_array(durations)).reshape((n,))
#     908 if weights is None:
#     909     weights = np.ones_like(durations)
#
# File ~\ANACONDA\lib\site-packages\lifelines\utils\__init__.py:970, in pass_for_numeric_dtypes_or_raise_array(x)
#     967     return v
#     969 except:
# --> 970     raise ValueError("Values must be numeric: no strings, datetimes, objects, etc.")
#
# ValueError: Values must be numeric: no strings, datetimes, objects, etc.

# %%
df["Time_overall_study"].value_counts()
# Out:
# 1.872728     4
# 2.168422     4
# 0.722807     3
# 9.100803     3
# 8.148011     3
#             ..
# 7.622333     1
# 22.407031    1
# 4.895378     1
# 6.800961     1
# 15.868909    1
# Name: Time_overall_study, Length: 320, dtype: int64

# %%
df.columns
# Out:
# Index(['Surgery_final', 'Status', 'Time_overall_study'], dtype='object')

# %%
import pandas as pd
from lifelines import KaplanMeierFitter

# Assuming df is your DataFrame
# Convert "Time_overall_study" to numeric (if not already)
df["Time_overall_study"] = pd.to_numeric(df["Time_overall_study"], errors="coerce")

# Drop rows with missing values
df = df.dropna(subset=["Time_overall_study", "Status"])

# Instantiate KaplanMeierFitter
kmf = KaplanMeierFitter()

# Iterate over treatment categories
for category in df["Treatment_final"].unique():
    subset = df[df["Treatment_final"] == category]
    
    # Check if the subset is not empty
    if not subset.empty:
        kmf.fit(subset["Time_overall_study"], event_observed=subset["Status"], label=category)
        # Plot or analyze the Kaplan-Meier curve as needed
# Plot the Kaplan-Meier curve
        kmf.plot(ci_show=False)

        # Calculate and print median survival time
        median_survival_time = kmf.median_survival_time_
        print(f"Median survival time for {category}: {median_survival_time:.2f} months")

        # Plot censored data points
        censored_data = subset[subset["Status"] == 0]
        plt.scatter(censored_data["Time_overall_study"], kmf.predict(censored_data["Time_overall_study"]),
            marker='x', color='black', s=50, label=f'Censored - {category}')
    
        # Calculate the risk table
        event_table = survival_table_from_events(subset["Time_overall_study"], subset["Status"])
        print(f"Risk table for {category}:\n{event_table}")
    
# Add title and labels to the plot
plt.title("Kaplan-Meier Survival Analysis w.r.t Treatment Type")
plt.xlabel("Time (months)")
plt.ylabel("Survival Probability")
plt.legend()

# Show the plot
plt.show()
# Out:
# Median survival time for Curative: 14.69 months
# Risk table for Curative:
#            removed  observed  censored  entrance  at_risk
# event_at
# 0.000000         0         0         0        29       29
# 0.919937         1         1         0         0       29
# 4.829668         1         1         0         0       28
# 6.275283         1         1         0         0       27
# 6.932381         1         1         0         0       26
# 7.655188         1         1         0         0       25
# 8.016592         1         1         0         0       24
# 9.133658         1         1         0         0       23
# 9.692191         1         1         0         0       22
# 10.283579        1         1         0         0       21
# 10.349288        1         1         0         0       20
# 10.447853        1         1         0         0       19
# 10.973531        1         1         0         0       18
# 11.926323        1         1         0         0       17
# 14.456149        1         1         0         0       16
# 14.686133        1         1         0         0       15
# 15.540360        1         1         0         0       14
# 16.328877        1         1         0         0       13
# 16.953120        1         1         0         0       12
# 18.135896        1         1         0         0       11
# 18.267316        1         1         0         0       10
# 18.563010        1         1         0         0        9
# 19.877205        1         1         0         0        8
# 20.008624        1         1         0         0        7
# 21.027126        1         1         0         0        6
# 23.162693        1         1         0         0        5
# 24.246904        1         1         0         0        4
# 25.363971        1         1         0         0        3
# 29.010863        1         1         0         0        2
# 30.226493        1         1         0         0        1
# Median survival time for Disease Control: 9.10 months
# Risk table for Disease Control:
#             removed  observed  censored  entrance  at_risk
# event_at
# 0.000000          0         0         0       252      252
# 0.065710          2         2         0         0      252
# 0.098565          1         1         0         0      250
# 0.131420          1         1         0         0      249
# 0.295694          1         1         0         0      248
# ...             ...       ...       ...       ...      ...
# 82.925727         1         1         0         0        5
# 97.546151         1         1         0         0        4
# 106.975503        1         1         0         0        3
# 107.172632        1         1         0         0        2
# 147.222736        1         1         0         0        1
#
# [216 rows x 5 columns]
# Median survival time for Palliative_care: 3.15 months
# Risk table for Palliative_care:
#            removed  observed  censored  entrance  at_risk
# event_at
# 0.000000         0         0         0       113      113
# 0.032855         1         1         0         0      113
# 0.328549         1         1         0         0      112
# 0.394259         1         1         0         0      111
# 0.492823         1         1         0         0      110
# ...            ...       ...       ...       ...      ...
# 13.109099        1         1         0         0        5
# 15.113247        1         1         0         0        4
# 15.343231        1         1         0         0        3
# 22.045627        1         1         0         0        2
# 22.932709        1         1         0         0        1
#
# [95 rows x 5 columns]

# %% [markdown]
# ## COX ph Model Analysis

# %%
df = data.copy()

# %%
df["Status"].value_counts()

# %%
# Replace "True" with 1 and "False" with 0 in the "Status" column
df['Status'] = df['Status'].replace({"True": 1, "False": 0})

# %%
df['Status'].value_counts()

# %%
df.columns

# %%
df.info()

# %%
#### Dropping Unnecessary columns from our analysis

# %%
data.to_csv("data_cox.csv", index=False)

# %%
df.columns

# %%
# Select categorical columns
categorical_columns = df.select_dtypes(include=['object'])

# Select continuous columns (excluding categorical)
continuous_columns = df.select_dtypes(exclude=['object'])

# %%
continuous_columns
