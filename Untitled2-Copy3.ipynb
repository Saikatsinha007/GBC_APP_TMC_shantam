# %% [markdown]
# ## COX PH MODEL ANALYSIS

# %%
# Import the required libraries & modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
gbc_patients = pd.read_excel("GBC.xlsx")

# %%
gbc_patients.head()
# Out:
#           MR_NO Comorbidities_final      Thyroidism Diabetes  HTN  \
# 0  MR/17/000051                 NaN              No       No  Yes
# 1  MR/17/000165                 NaN              No       No   No
# 2  MR/17/000504                 NaN  Hypothyroidism      Yes  Yes
# 3  MR/17/000600                 NaN              No       No  Yes
# 4  MR/17/000665                 NaN              No       No   No
#
#   Family_cancer_history ECOG_final Gall_stone_final       Pathology  \
# 0                    No          1              Yes  Adenocarcinoma
# 1                    No  Not known               No  Adenocarcinoma
# 2             Not known  Not known        Not known  Adenocarcinoma
# 3                    No          1               No  Adenocarcinoma
# 4                    No          1        Not known  Adenocarcinoma
#
#   Tumour_grade_final  ... ALT - SGPT ALK PHOS [ALP] GAMMA GT ALBUMIN  \
# 0            Grade 3  ...       28.0          147.0     21.0     4.7
# 1            Grade X  ...       27.0           83.0     76.0     3.4
# 2            Grade 3  ...        NaN            NaN      NaN     NaN
# 3            Grade X  ...       98.0          481.0     83.0     4.1
# 4            Grade X  ...       78.0          206.0    481.0     3.2
#
#   CREATININE_from_UnC_test UREA_from_UnC_test ESTIMATED AVERAGE GLUCOSE (eAG)  \
# 0                      NaN                NaN                           137.0
# 1                      NaN                NaN                             NaN
# 2                      NaN                NaN                             NaN
# 3                      NaN                NaN                           117.0
# 4                      NaN                NaN                             NaN
#
#   HbA1c CREATININE_from_CREATININE_test Diabetes_final
# 0   6.4                            0.64            Yes
# 1   NaN                             NaN             No
# 2   NaN                             NaN            Yes
# 3   5.7                            1.08            Yes
# 4   NaN                            0.60             No
#
# [5 rows x 50 columns]

# %%
filtered_data = gbc_patients.dropna(subset=[ 'Status','Date_event', 'Date_diagnosis'])
filtered_data.shape
# Out:
# (426, 50)

# %%
filtered_data["Status"].value_counts()
# Out:
# Dead    425
# No        1
# Name: Status, dtype: int64

# %%
# Calculate the difference of Date_event and Date_diagnosis in months
filtered_data['Time_overall_study'] = ((filtered_data['Date_event'] - filtered_data['Date_diagnosis']) / np.timedelta64(1, 'M')).astype(float)

filtered_data.head()
# Out:
# C:\Users\sriva\AppData\Local\Temp\ipykernel_45380\2160711339.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['Time_overall_study'] = ((filtered_data['Date_event'] - filtered_data['Date_diagnosis']) / np.timedelta64(1, 'M')).astype(float)
#           MR_NO Comorbidities_final      Thyroidism   Diabetes  HTN  \
# 0  MR/17/000051                 NaN              No         No  Yes
# 4  MR/17/000665                 NaN              No         No   No
# 5  MR/17/000682                 NaN              No         No  Yes
# 7  MR/17/001311       Heart disease              No        Yes  Yes
# 8  MR/17/001536                 NaN  Hypothyroidism  Not known  Yes
#
#   Family_cancer_history ECOG_final Gall_stone_final       Pathology  \
# 0                    No          1              Yes  Adenocarcinoma
# 4                    No          1        Not known  Adenocarcinoma
# 5                    No          2              Yes  Adenocarcinoma
# 7             Not known          1              Yes           MiNEN
# 8             Not known  Not known              Yes  Adenocarcinoma
#
#   Tumour_grade_final  ... ALK PHOS [ALP] GAMMA GT ALBUMIN  \
# 0            Grade 3  ...          147.0     21.0     4.7
# 4            Grade X  ...          206.0    481.0     3.2
# 5            Grade X  ...            NaN      NaN     NaN
# 7            Grade 2  ...          108.0     21.0     4.6
# 8            Grade X  ...          492.0    209.0     2.6
#
#   CREATININE_from_UnC_test UREA_from_UnC_test ESTIMATED AVERAGE GLUCOSE (eAG)  \
# 0                      NaN                NaN                           137.0
# 4                      NaN                NaN                             NaN
# 5                      NaN                NaN                             NaN
# 7                      NaN                NaN                             NaN
# 8                      NaN                NaN                             NaN
#
#   HbA1c CREATININE_from_CREATININE_test Diabetes_final Time_overall_study
# 0   6.4                            0.64            Yes          24.246904
# 4   NaN                            0.60             No          11.860613
# 5   NaN                            0.61             No          17.248814
# 7   NaN                             NaN            Yes          23.852646
# 8   NaN                             NaN      Not known          12.846260
#
# [5 rows x 51 columns]

# %%
# Replace 'column_name' with the actual name of your column
row = filtered_data[filtered_data['Time_overall_study'] == -8.01659171646235]

print(row["Status"])
print(row["Date_event"])
print(row["Date_diagnosis"])
# Out:
# 657    Dead
# Name: Status, dtype: object
# 657   2019-02-23
# Name: Date_event, dtype: datetime64[ns]
# 657   2019-10-25
# Name: Date_diagnosis, dtype: datetime64[ns]

# %%
#Time_overall_study feature
value_to_delete = -8.01659171646235

# Delete the row with the specified value
filtered_data = filtered_data[filtered_data['Time_overall_study'] != value_to_delete]

filtered_data.shape
# Out:
# (425, 51)

# %%
# Mapping of values to be replaced
status_mapping = {'Dead': 1, 'No': 0}

# Replace values in the "Status" column
filtered_data['Status'] = filtered_data['Status'].replace(status_mapping)

# %%
filtered_data['Status'].value_counts()
# Out:
# 1    424
# 0      1
# Name: Status, dtype: int64

# %%
df = filtered_data.copy()

# %%
###########################################################

# %% [markdown]
# ## Cox PH Model Analysis

# %%
df.shape
# Out:
# (425, 51)

# %%
df['Status'].value_counts()
# Out:
# 1    424
# 0      1
# Name: Status, dtype: int64

# %%
df.columns
# Out:
# Index(['MR_NO', 'Comorbidities_final', 'Thyroidism', 'Diabetes', 'HTN',
#        'Family_cancer_history', 'ECOG_final', 'Gall_stone_final', 'Pathology',
#        'Tumour_grade_final', 'Cancer_presentation_final', 'Tumour_stage_final',
#        'TNM_classification', 'Metastasis_final', 'Site_metastasis',
#        'Mets_site_final', 'Cholecystectomy_TMC', 'Outside_cholecystectomy',
#        'Surgery_final', 'Treatment_final', 'Treatment_clean', 'Treatment',
#        'Status', 'Date_event', 'Date_diagnosis', 'AGE', 'GENDER', 'COUNTRY',
#        'STATE_NAME', 'CITY_NAME', 'PINCODE', 'First_Visit_Date', 'HEIGHT',
#        'WEIGHT', 'BSA_DETAILS', 'BMI_DETAILS', 'BILIRUBIN CONJUGATED',
#        'BILIRUBIN UNCONJUGATED', 'BILIRUBIN TOTAL', 'AST - SGOT', 'ALT - SGPT',
#        'ALK PHOS [ALP]', 'GAMMA GT', 'ALBUMIN', 'CREATININE_from_UnC_test',
#        'UREA_from_UnC_test', 'ESTIMATED AVERAGE GLUCOSE (eAG)', 'HbA1c',
#        'CREATININE_from_CREATININE_test', 'Diabetes_final',
#        'Time_overall_study'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 425 entries, 0 to 695
# Data columns (total 51 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   MR_NO                            425 non-null    object
#  1   Comorbidities_final              351 non-null    object
#  2   Thyroidism                       406 non-null    object
#  3   Diabetes                         408 non-null    object
#  4   HTN                              408 non-null    object
#  5   Family_cancer_history            406 non-null    object
#  6   ECOG_final                       409 non-null    object
#  7   Gall_stone_final                 407 non-null    object
#  8   Pathology                        425 non-null    object
#  9   Tumour_grade_final               403 non-null    object
#  10  Cancer_presentation_final        400 non-null    object
#  11  Tumour_stage_final               384 non-null    object
#  12  TNM_classification               382 non-null    object
#  13  Metastasis_final                 398 non-null    object
#  14  Site_metastasis                  345 non-null    object
#  15  Mets_site_final                  397 non-null    object
#  16  Cholecystectomy_TMC              297 non-null    object
#  17  Outside_cholecystectomy          406 non-null    object
#  18  Surgery_final                    409 non-null    object
#  19  Treatment_final                  394 non-null    object
#  20  Treatment_clean                  391 non-null    object
#  21  Treatment                        391 non-null    object
#  22  Status                           425 non-null    int64
#  23  Date_event                       425 non-null    datetime64[ns]
#  24  Date_diagnosis                   425 non-null    datetime64[ns]
#  25  AGE                              425 non-null    int64
#  26  GENDER                           425 non-null    object
#  27  COUNTRY                          425 non-null    object
#  28  STATE_NAME                       425 non-null    object
#  29  CITY_NAME                        425 non-null    object
#  30  PINCODE                          417 non-null    float64
#  31  First_Visit_Date                 349 non-null    datetime64[ns]
#  32  HEIGHT                           349 non-null    float64
#  33  WEIGHT                           349 non-null    float64
#  34  BSA_DETAILS                      349 non-null    float64
#  35  BMI_DETAILS                      349 non-null    float64
#  36  BILIRUBIN CONJUGATED             272 non-null    float64
#  37  BILIRUBIN UNCONJUGATED           272 non-null    float64
#  38  BILIRUBIN TOTAL                  272 non-null    float64
#  39  AST - SGOT                       272 non-null    float64
#  40  ALT - SGPT                       271 non-null    float64
#  41  ALK PHOS [ALP]                   272 non-null    float64
#  42  GAMMA GT                         271 non-null    float64
#  43  ALBUMIN                          272 non-null    float64
#  44  CREATININE_from_UnC_test         13 non-null     float64
#  45  UREA_from_UnC_test               13 non-null     float64
#  46  ESTIMATED AVERAGE GLUCOSE (eAG)  47 non-null     float64
#  47  HbA1c                            47 non-null     float64
#  48  CREATININE_from_CREATININE_test  117 non-null    float64
#  49  Diabetes_final                   408 non-null    object
#  50  Time_overall_study               425 non-null    float64
# dtypes: datetime64[ns](3), float64(19), int64(2), object(27)
# memory usage: 172.7+ KB

# %%
# Filter columns with object data type
categorical_columns = df.select_dtypes(include=['object']).columns

# Calculate counts of each category in categorical features
category_counts = {}

for column in categorical_columns:
    counts = df[column].value_counts()
    category_counts[column] = counts

# Print the counts of each category in categorical features
for column, counts in category_counts.items():
    print(f'Counts for {column}:')
    print(counts)
    print()
# Out:
# Counts for MR_NO:
# MR/17/000051    1
# MR/18/015094    1
# MR/18/014781    1
# MR/18/014136    1
# MR/18/014086    1
#                ..
# MR/17/015787    1
# MR/17/015628    1
# MR/17/014162    1
# MR/17/014043    1
# MR/19/001762    1
# Name: MR_NO, Length: 425, dtype: int64
#
# Counts for Comorbidities_final:
# No                254
# Not known          63
# Heart disease      17
# Lungs disease       9
# Kidney disease      4
# Other cancer        4
# Name: Comorbidities_final, dtype: int64
#
# Counts for Thyroidism:
# No                305
# Not known          66
# Hypothyroidism     35
# Name: Thyroidism, dtype: int64
#
# Counts for Diabetes:
# No           240
# Yes          103
# Not known     65
# Name: Diabetes, dtype: int64
#
# Counts for HTN:
# No           207
# Yes          141
# Not known     60
# Name: HTN, dtype: int64
#
# Counts for Family_cancer_history:
# Not known    215
# No           154
# Yes           37
# Name: Family_cancer_history, dtype: int64
#
# Counts for ECOG_final:
# 1            221
# 2             92
# 3             37
# Not known     29
# 4             16
# 0             14
# Name: ECOG_final, dtype: int64
#
# Counts for Gall_stone_final:
# Yes          171
# Not known    118
# No           117
# Polyp          1
# Name: Gall_stone_final, dtype: int64
#
# Counts for Pathology:
# Adenocarcinoma                  359
# Carcinoma                        31
# Adenosquamous carcinoma          14
# Neuroendocrine carcinoma          7
# Others                            7
# Mucinous adenocarcinoma           3
# MiNEN                             2
# ICPN with invasive carcinoma      2
# Name: Pathology, dtype: int64
#
# Counts for Tumour_grade_final:
# Grade X    207
# Grade 3    107
# Grade 2     78
# Grade 1     10
# Grade 4      1
# Name: Tumour_grade_final, dtype: int64
#
# Counts for Cancer_presentation_final:
# Metastatic          239
# Incidental           99
# Locally advanced     62
# Name: Cancer_presentation_final, dtype: int64
#
# Counts for Tumour_stage_final:
# Stage IV     277
# Stage III     55
# Not known     38
# Stage II      14
# Name: Tumour_stage_final, dtype: int64
#
# Counts for TNM_classification:
# T3N1M1       40
# TxNxM1       40
# T3N1M0       30
# T3NxM1       20
# T3N2M1       19
# TxN2M1       15
# T3N2M0       13
# T2N2M1       13
# T4N1M0       12
# T2N1M0       12
# T2N0M0       12
# T2N1M1       11
# TxN1M1       10
# T3N0M0       10
# T3N0M1        8
# T2NxM0        8
# T2N2M0        8
# Not Known     8
# T4N0M1        7
# T3NxMx        7
# TxN2M0        7
# T4N2M1        6
# T4NxM1        6
# T4N0M0        6
# T3NxM0        5
# TxN0M1        5
# T2NxM1        5
# T2N0M1        4
# T4N1M1        4
# T4N2M0        3
# T2NxMx        3
# T1N2M0        3
# TxN1M0        3
# T4NxMx        2
# TxN2Mx        2
# T4NxM0        2
# T2bN0M0       2
# T2N2Mx        1
# T3N1          1
# T1N1M0        1
# T2bN2M0       1
# T1N0Mx        1
# T1N2M1        1
# T2aN1M1       1
# T2bN1M0       1
# T3NXM0        1
# T2aN1M0       1
# T1N0M1        1
# Name: TNM_classification, dtype: int64
#
# Counts for Metastasis_final:
# Yes          240
# No           137
# Not known     21
# Name: Metastasis_final, dtype: int64
#
# Counts for Site_metastasis:
# Liver                  123
# Not Applicable          56
# Not applicable          48
# Omentum                 14
# Peritoneum               7
#                       ...
# Peritonum                1
# Mesentery                1
# Lung and Peritoneam      1
# Peritomeum               1
# Lungs-adrenal            1
# Name: Site_metastasis, Length: 73, dtype: int64
#
# Counts for Mets_site_final:
# Not applicable          158
# Liver                   142
# Peritoneum & Omentum     34
# Lungs                    16
# Liver & Lungs             9
# Portsite                  8
# Liver & Bone              7
# Stomach & Intestine       5
# Pancreas                  3
# Ovary & Uterus            3
# Adrenal gland             2
# Not known                 2
# Right hypochondrium       2
# Lungs and bone            1
# Bone                      1
# Chest                     1
# FALSE                     1
# Lung,Bone                 1
# Brain                     1
# Name: Mets_site_final, dtype: int64
#
# Counts for Cholecystectomy_TMC:
# No                     143
# Not applicable          59
# Inoperable              46
# Radical                 28
# Staging Lap              6
# Staging laparoscopy      5
# Stagging_lap             3
# Staging laparotomy       2
# Unresectable             2
# Open                     2
# Right hepatectomy        1
# Name: Cholecystectomy_TMC, dtype: int64
#
# Counts for Outside_cholecystectomy:
# No         256
# Simple     132
# Radical     15
# Partial      3
# Name: Outside_cholecystectomy, dtype: int64
#
# Counts for Surgery_final:
# No         249
# Simple     114
# Radical     43
# Partial      3
# Name: Surgery_final, dtype: int64
#
# Counts for Treatment_final:
# Disease Control    252
# Palliative_care    113
# Curative            29
# Name: Treatment_final, dtype: int64
#
# Counts for Treatment_clean:
# Chemotherapy                 138
# Palliative-care               97
# Surgery                       61
# Surgery-chemotherapy          56
# No                            30
# Chemo-radiotherapy             6
# Surgery-chemoradiotherapy      3
# Name: Treatment_clean, dtype: int64
#
# Counts for Treatment:
# Palliative chemotherapy                      105
# Palliative                                    55
# Surgery                                       52
# Palliative care                               29
# Not Applicable                                26
# Chemotherapy                                  26
# Surgery and chemotherapy                      25
# Surgery-chemotherapy                          22
# Palliation                                    12
# Curative surgery                               7
# NACT                                           4
# Curative surgery, Chemotherapy                 3
# Not Known                                      3
# Chemotherapy, Radiotherapy                     2
# Adjuvant chemotherapy                          2
# Curative surgery & chemotherapy                2
# CTRT                                           2
# Palliative Chemotherapy                        2
# Surgery+CR-RT                                  1
# Systemic chemotherapy                          1
# Surgery and Chemotherapy and radiotherapy      1
# Adjuvant CTRT                                  1
# Palliative Radiation treatment                 1
# Curative                                       1
# Radiotherapy, chemotherapy                     1
# Radical treatment                              1
# Chemotherapy (outside)                         1
# Stenting and chemotherapy                      1
# Treatment not possible                         1
# Surgery-CTRT                                   1
# Name: Treatment, dtype: int64
#
# Counts for GENDER:
# FEMA    287
# MALE    138
# Name: GENDER, dtype: int64
#
# Counts for COUNTRY:
# IN    425
# Name: COUNTRY, dtype: int64
#
# Counts for STATE_NAME:
# WB    325
# BR     32
# JH     31
# AS     11
# OR      6
# UP      6
# TR      5
# MN      4
# KA      1
# MP      1
# MH      1
# RJ      1
# GJ      1
# Name: STATE_NAME, dtype: int64
#
# Counts for CITY_NAME:
# KOLKATA              68
# 24 PARGANAS NORTH    57
# 24 PARGANAS SOUTH    31
# HOOGHLY              21
# BURDWAN              19
#                      ..
# PUNE                  1
# GUWAHATI              1
# KARIMGANJ             1
# BALASORE              1
# NAGAON                1
# Name: CITY_NAME, Length: 85, dtype: int64
#
# Counts for Diabetes_final:
# No           231
# Yes          115
# Not known     62
# Name: Diabetes_final, dtype: int64

# %%
#### Dropping Unnecessary columns from our analysis

# %% [markdown]
# #### Removal of variables here is purely on the basis of assumptions as I am not the domain expert.
# **Variables with a lot of categories, or features that contain a lot of missing values, date time features, and some unnecessary features were removed on a pure basis of choice.**
# **The cox ph model analysis will change as the variables taken into the account, changes**

# %%
# List of columns to drop
columns_to_drop = ['MR_NO', 'COUNTRY','STATE_NAME', 'PINCODE', 'CITY_NAME','First_Visit_Date', 'Date_diagnosis','Date_event','UREA_from_UnC_test','CREATININE_from_UnC_test','ESTIMATED AVERAGE GLUCOSE (eAG)','HbA1c', 'CREATININE_from_CREATININE_test','Site_metastasis', 'TNM_classification','Family_cancer_history','Tumour_grade_final', 'Pathology', 'Metastasis_final','Mets_site_final','Treatment_clean', 'Treatment', 'Cholecystectomy_TMC', 'Outside_cholecystectomy','Diabetes','Cancer_presentation_final','Thyroidism','HTN']

# Drop the specified columns
df = df.drop(columns=columns_to_drop)

# %%
df.columns
# Out:
# Index(['Comorbidities_final', 'ECOG_final', 'Gall_stone_final',
#        'Tumour_stage_final', 'Surgery_final', 'Treatment_final', 'Status',
#        'AGE', 'GENDER', 'HEIGHT', 'WEIGHT', 'BSA_DETAILS', 'BMI_DETAILS',
#        'BILIRUBIN CONJUGATED', 'BILIRUBIN UNCONJUGATED', 'BILIRUBIN TOTAL',
#        'AST - SGOT', 'ALT - SGPT', 'ALK PHOS [ALP]', 'GAMMA GT', 'ALBUMIN',
#        'Diabetes_final', 'Time_overall_study'],
#       dtype='object')

# %%
# Drop rows with any missing values
clean_data = df.dropna()

print("Cleaned DataFrame:")
print(clean_data.shape)
# Out:
# Cleaned DataFrame:
# (203, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 425 entries, 0 to 695
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Comorbidities_final     351 non-null    object
#  1   ECOG_final              409 non-null    object
#  2   Gall_stone_final        407 non-null    object
#  3   Tumour_stage_final      384 non-null    object
#  4   Surgery_final           409 non-null    object
#  5   Treatment_final         394 non-null    object
#  6   Status                  425 non-null    int64
#  7   AGE                     425 non-null    int64
#  8   GENDER                  425 non-null    object
#  9   HEIGHT                  349 non-null    float64
#  10  WEIGHT                  349 non-null    float64
#  11  BSA_DETAILS             349 non-null    float64
#  12  BMI_DETAILS             349 non-null    float64
#  13  BILIRUBIN CONJUGATED    272 non-null    float64
#  14  BILIRUBIN UNCONJUGATED  272 non-null    float64
#  15  BILIRUBIN TOTAL         272 non-null    float64
#  16  AST - SGOT              272 non-null    float64
#  17  ALT - SGPT              271 non-null    float64
#  18  ALK PHOS [ALP]          272 non-null    float64
#  19  GAMMA GT                271 non-null    float64
#  20  ALBUMIN                 272 non-null    float64
#  21  Diabetes_final          408 non-null    object
#  22  Time_overall_study      425 non-null    float64
# dtypes: float64(13), int64(2), object(8)
# memory usage: 79.7+ KB

# %%
# Filter columns with object data type
categorical_columns = df.select_dtypes(include=['object']).columns

# Calculate counts of each category in categorical features
category_counts = {}

for column in categorical_columns:
    counts = df[column].value_counts()
    category_counts[column] = counts

# Print the counts of each category in categorical features
for column, counts in category_counts.items():
    print(f'Counts for {column}:')
    print(counts)
    print()
# Out:
# Counts for Comorbidities_final:
# No                254
# Not known          63
# Heart disease      17
# Lungs disease       9
# Kidney disease      4
# Other cancer        4
# Name: Comorbidities_final, dtype: int64
#
# Counts for ECOG_final:
# 1            221
# 2             92
# 3             37
# Not known     29
# 4             16
# 0             14
# Name: ECOG_final, dtype: int64
#
# Counts for Gall_stone_final:
# Yes          171
# Not known    118
# No           117
# Polyp          1
# Name: Gall_stone_final, dtype: int64
#
# Counts for Tumour_stage_final:
# Stage IV     277
# Stage III     55
# Not known     38
# Stage II      14
# Name: Tumour_stage_final, dtype: int64
#
# Counts for Surgery_final:
# No         249
# Simple     114
# Radical     43
# Partial      3
# Name: Surgery_final, dtype: int64
#
# Counts for Treatment_final:
# Disease Control    252
# Palliative_care    113
# Curative            29
# Name: Treatment_final, dtype: int64
#
# Counts for GENDER:
# FEMA    287
# MALE    138
# Name: GENDER, dtype: int64
#
# Counts for Diabetes_final:
# No           231
# Yes          115
# Not known     62
# Name: Diabetes_final, dtype: int64

# %%
# Select categorical columns
categorical_columns = clean_data.select_dtypes(include=['object'])

# Select continuous columns (excluding categorical)
continuous_columns = clean_data.select_dtypes(exclude=['object'])

# %%
continuous_columns
# Out:
#      Status  AGE  HEIGHT  WEIGHT  BSA_DETAILS  BMI_DETAILS  \
# 7         1   62   166.4    56.0         1.61        20.22
# 20        1   71   169.9    57.4         1.65        19.88
# 57        1   73     0.0     0.0         0.00         0.00
# 76        1   42   157.5    38.3         1.29        15.44
# 100       1   52   140.5    40.7         1.26        20.62
# ..      ...  ...     ...     ...          ...          ...
# 674       1   74   146.0    55.2         1.50        25.90
# 675       1   67   140.5    35.4         1.18        17.93
# 678       1   62   155.5    38.0         1.28        15.72
# 686       1   50   162.0    68.2         1.75        25.99
# 689       1   60   148.2    48.6         1.41        22.13
#
#      BILIRUBIN CONJUGATED  BILIRUBIN UNCONJUGATED  BILIRUBIN TOTAL  \
# 7                     0.0                     1.0              1.0
# 20                    0.0                     0.6              0.6
# 57                    0.0                     0.3              1.7
# 76                    0.0                     0.6              0.6
# 100                   0.7                     0.3              2.4
# ..                    ...                     ...              ...
# 674                   0.0                     0.6              0.6
# 675                   0.0                     0.1              0.3
# 678                   0.0                     0.1              0.5
# 686                   0.2                     0.7              1.8
# 689                   0.0                     0.3              0.3
#
#      AST - SGOT  ALT - SGPT  ALK PHOS [ALP]  GAMMA GT  ALBUMIN  \
# 7          36.0        31.0           108.0      21.0      4.6
# 20         19.0        10.0            74.0      18.0      4.2
# 57         72.0        54.0           604.0    1015.0      3.5
# 76         27.0        35.0           151.0      40.0      3.6
# 100        65.0       186.0           524.0     321.0      3.4
# ..          ...         ...             ...       ...      ...
# 674        38.0        20.0           136.0      53.0      3.3
# 675       118.0        35.0           287.0     243.0      3.9
# 678        39.0        30.0           232.0      96.0      3.5
# 686       108.0        75.0           598.0      75.0      3.4
# 689        25.0        29.0           113.0      38.0      3.8
#
#      Time_overall_study
# 7             23.852646
# 20            10.283579
# 57             6.143863
# 76            16.460297
# 100            5.486766
# ..                  ...
# 674            8.148011
# 675            6.439557
# 678            4.928233
# 686            2.694100
# 689           11.959178
#
# [203 rows x 15 columns]

# %%
continuous_columns
# Out:
#      Status  AGE  HEIGHT  WEIGHT  BSA_DETAILS  BMI_DETAILS  \
# 7         1   62   166.4    56.0         1.61        20.22
# 20        1   71   169.9    57.4         1.65        19.88
# 57        1   73     0.0     0.0         0.00         0.00
# 76        1   42   157.5    38.3         1.29        15.44
# 100       1   52   140.5    40.7         1.26        20.62
# ..      ...  ...     ...     ...          ...          ...
# 674       1   74   146.0    55.2         1.50        25.90
# 675       1   67   140.5    35.4         1.18        17.93
# 678       1   62   155.5    38.0         1.28        15.72
# 686       1   50   162.0    68.2         1.75        25.99
# 689       1   60   148.2    48.6         1.41        22.13
#
#      BILIRUBIN CONJUGATED  BILIRUBIN UNCONJUGATED  BILIRUBIN TOTAL  \
# 7                     0.0                     1.0              1.0
# 20                    0.0                     0.6              0.6
# 57                    0.0                     0.3              1.7
# 76                    0.0                     0.6              0.6
# 100                   0.7                     0.3              2.4
# ..                    ...                     ...              ...
# 674                   0.0                     0.6              0.6
# 675                   0.0                     0.1              0.3
# 678                   0.0                     0.1              0.5
# 686                   0.2                     0.7              1.8
# 689                   0.0                     0.3              0.3
#
#      AST - SGOT  ALT - SGPT  ALK PHOS [ALP]  GAMMA GT  ALBUMIN  \
# 7          36.0        31.0           108.0      21.0      4.6
# 20         19.0        10.0            74.0      18.0      4.2
# 57         72.0        54.0           604.0    1015.0      3.5
# 76         27.0        35.0           151.0      40.0      3.6
# 100        65.0       186.0           524.0     321.0      3.4
# ..          ...         ...             ...       ...      ...
# 674        38.0        20.0           136.0      53.0      3.3
# 675       118.0        35.0           287.0     243.0      3.9
# 678        39.0        30.0           232.0      96.0      3.5
# 686       108.0        75.0           598.0      75.0      3.4
# 689        25.0        29.0           113.0      38.0      3.8
#
#      Time_overall_study
# 7             23.852646
# 20            10.283579
# 57             6.143863
# 76            16.460297
# 100            5.486766
# ..                  ...
# 674            8.148011
# 675            6.439557
# 678            4.928233
# 686            2.694100
# 689           11.959178
#
# [203 rows x 15 columns]

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming continuous_columns is a NumPy array
# Define your column names (replace with actual column names)
column_names = continuous_columns.columns.tolist()  # List of column names

# Convert it to a Pandas DataFrame
continuous_columns_df = pd.DataFrame(continuous_columns, columns=column_names)

# Calculate correlation matrix
correlation_matrix = continuous_columns_df.corr()

# Rest of your code remains the same
# Set up the matplotlib figure
plt.figure(figsize=(12, 10))

# Generate a heatmap
sns.set(font_scale=1)  # Adjust font size for annotations
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", center=0, linewidths=0.5)

# Add plot title
plt.title("Correlation Heatmap")

# Show the plot
plt.tight_layout()
plt.show()

# Function to remove highly correlated variables
def remove_highly_correlated(continuous_columns_df, threshold=0.9):
    corr_matrix = continuous_columns_df.corr().abs()
    upper_tri = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
    to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > threshold)]
    continuous_columns_df = continuous_columns_df.drop(columns=to_drop)
    return continuous_columns_df

# Remove highly correlated variables
threshold = 0.9
continuous_columns_no_high_correlation = remove_highly_correlated(continuous_columns_df, threshold)

print("Original DataFrame shape:", continuous_columns_df.shape)
print("DataFrame after removing highly correlated variables shape:", continuous_columns_no_high_correlation.shape)
# Out:
# Original DataFrame shape: (203, 15)
# DataFrame after removing highly correlated variables shape: (203, 13)
# C:\Users\sriva\AppData\Local\Temp\ipykernel_45380\743500439.py:34: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   upper_tri = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# %%
##performing one hot encoding to the categorical variables in order to pass the weightage of categorical variables in the form of numbers to our model.

# %%
# Perform one-hot encoding on categorical columns
encoded_categorical = pd.get_dummies(categorical_columns, drop_first=True)

# %%
encoded_categorical.isnull().sum()
# Out:
# Comorbidities_final_Kidney disease    0
# Comorbidities_final_Lungs disease     0
# Comorbidities_final_No                0
# Comorbidities_final_Not known         0
# Comorbidities_final_Other cancer      0
# ECOG_final_1                          0
# ECOG_final_2                          0
# ECOG_final_3                          0
# ECOG_final_4                          0
# ECOG_final_Not known                  0
# Gall_stone_final_Not known            0
# Gall_stone_final_Polyp                0
# Gall_stone_final_Yes                  0
# Tumour_stage_final_Stage II           0
# Tumour_stage_final_Stage III          0
# Tumour_stage_final_Stage IV           0
# Surgery_final_Partial                 0
# Surgery_final_Radical                 0
# Surgery_final_Simple                  0
# Treatment_final_Disease Control       0
# Treatment_final_Palliative_care       0
# GENDER_MALE                           0
# Diabetes_final_Not known              0
# Diabetes_final_Yes                    0
# dtype: int64

# %%
print(encoded_categorical.isnull().sum())
print("*********************************")
print(continuous_columns_no_high_correlation.isnull().sum())
# Out:
# Comorbidities_final_Kidney disease    0
# Comorbidities_final_Lungs disease     0
# Comorbidities_final_No                0
# Comorbidities_final_Not known         0
# Comorbidities_final_Other cancer      0
# ECOG_final_1                          0
# ECOG_final_2                          0
# ECOG_final_3                          0
# ECOG_final_4                          0
# ECOG_final_Not known                  0
# Gall_stone_final_Not known            0
# Gall_stone_final_Polyp                0
# Gall_stone_final_Yes                  0
# Tumour_stage_final_Stage II           0
# Tumour_stage_final_Stage III          0
# Tumour_stage_final_Stage IV           0
# Surgery_final_Partial                 0
# Surgery_final_Radical                 0
# Surgery_final_Simple                  0
# Treatment_final_Disease Control       0
# Treatment_final_Palliative_care       0
# GENDER_MALE                           0
# Diabetes_final_Not known              0
# Diabetes_final_Yes                    0
# dtype: int64
# *********************************
# Status                    0
# AGE                       0
# HEIGHT                    0
# WEIGHT                    0
# BILIRUBIN CONJUGATED      0
# BILIRUBIN UNCONJUGATED    0
# BILIRUBIN TOTAL           0
# AST - SGOT                0
# ALT - SGPT                0
# ALK PHOS [ALP]            0
# GAMMA GT                  0
# ALBUMIN                   0
# Time_overall_study        0
# dtype: int64

# %%
## Taking only 196 observations into the analysis

# %%
##performing one hot encoding to the categorical variables in order to pass the weightage of categorical variables in the form of numbers to our model.

# %%
# Concatenate the encoded categorical columns with continuous columns
working_dataframe = pd.concat([encoded_categorical, continuous_columns_no_high_correlation], axis=1)

# %%
working_dataframe.columns
# Out:
# Index(['Comorbidities_final_Kidney disease',
#        'Comorbidities_final_Lungs disease', 'Comorbidities_final_No',
#        'Comorbidities_final_Not known', 'Comorbidities_final_Other cancer',
#        'ECOG_final_1', 'ECOG_final_2', 'ECOG_final_3', 'ECOG_final_4',
#        'ECOG_final_Not known', 'Gall_stone_final_Not known',
#        'Gall_stone_final_Polyp', 'Gall_stone_final_Yes',
#        'Tumour_stage_final_Stage II', 'Tumour_stage_final_Stage III',
#        'Tumour_stage_final_Stage IV', 'Surgery_final_Partial',
#        'Surgery_final_Radical', 'Surgery_final_Simple',
#        'Treatment_final_Disease Control', 'Treatment_final_Palliative_care',
#        'GENDER_MALE', 'Diabetes_final_Not known', 'Diabetes_final_Yes',
#        'Status', 'AGE', 'HEIGHT', 'WEIGHT', 'BILIRUBIN CONJUGATED',
#        'BILIRUBIN UNCONJUGATED', 'BILIRUBIN TOTAL', 'AST - SGOT', 'ALT - SGPT',
#        'ALK PHOS [ALP]', 'GAMMA GT', 'ALBUMIN', 'Time_overall_study'],
#       dtype='object')

# %%
df = working_dataframe.copy()

# %%
df
# Out:
#      Comorbidities_final_Kidney disease  Comorbidities_final_Lungs disease  \
# 7                                     0                                  0
# 20                                    0                                  1
# 57                                    0                                  0
# 76                                    1                                  0
# 100                                   0                                  0
# ..                                  ...                                ...
# 674                                   0                                  0
# 675                                   0                                  0
# 678                                   0                                  0
# 686                                   0                                  0
# 689                                   0                                  0
#
#      Comorbidities_final_No  Comorbidities_final_Not known  \
# 7                         0                              0
# 20                        0                              0
# 57                        0                              0
# 76                        0                              0
# 100                       1                              0
# ..                      ...                            ...
# 674                       1                              0
# 675                       1                              0
# 678                       1                              0
# 686                       1                              0
# 689                       1                              0
#
#      Comorbidities_final_Other cancer  ECOG_final_1  ECOG_final_2  \
# 7                                   0             1             0
# 20                                  0             1             0
# 57                                  0             0             1
# 76                                  0             1             0
# 100                                 0             1             0
# ..                                ...           ...           ...
# 674                                 0             1             0
# 675                                 0             1             0
# 678                                 0             1             0
# 686                                 0             1             0
# 689                                 0             1             0
#
#      ECOG_final_3  ECOG_final_4  ECOG_final_Not known  ...  WEIGHT  \
# 7               0             0                     0  ...    56.0
# 20              0             0                     0  ...    57.4
# 57              0             0                     0  ...     0.0
# 76              0             0                     0  ...    38.3
# 100             0             0                     0  ...    40.7
# ..            ...           ...                   ...  ...     ...
# 674             0             0                     0  ...    55.2
# 675             0             0                     0  ...    35.4
# 678             0             0                     0  ...    38.0
# 686             0             0                     0  ...    68.2
# 689             0             0                     0  ...    48.6
#
#      BILIRUBIN CONJUGATED  BILIRUBIN UNCONJUGATED  BILIRUBIN TOTAL  \
# 7                     0.0                     1.0              1.0
# 20                    0.0                     0.6              0.6
# 57                    0.0                     0.3              1.7
# 76                    0.0                     0.6              0.6
# 100                   0.7                     0.3              2.4
# ..                    ...                     ...              ...
# 674                   0.0                     0.6              0.6
# 675                   0.0                     0.1              0.3
# 678                   0.0                     0.1              0.5
# 686                   0.2                     0.7              1.8
# 689                   0.0                     0.3              0.3
#
#      AST - SGOT  ALT - SGPT  ALK PHOS [ALP]  GAMMA GT  ALBUMIN  \
# 7          36.0        31.0           108.0      21.0      4.6
# 20         19.0        10.0            74.0      18.0      4.2
# 57         72.0        54.0           604.0    1015.0      3.5
# 76         27.0        35.0           151.0      40.0      3.6
# 100        65.0       186.0           524.0     321.0      3.4
# ..          ...         ...             ...       ...      ...
# 674        38.0        20.0           136.0      53.0      3.3
# 675       118.0        35.0           287.0     243.0      3.9
# 678        39.0        30.0           232.0      96.0      3.5
# 686       108.0        75.0           598.0      75.0      3.4
# 689        25.0        29.0           113.0      38.0      3.8
#
#      Time_overall_study
# 7             23.852646
# 20            10.283579
# 57             6.143863
# 76            16.460297
# 100            5.486766
# ..                  ...
# 674            8.148011
# 675            6.439557
# 678            4.928233
# 686            2.694100
# 689           11.959178
#
# [203 rows x 37 columns]

# %%
df.isnull().sum()
# Out:
# Comorbidities_final_Kidney disease    0
# Comorbidities_final_Lungs disease     0
# Comorbidities_final_No                0
# Comorbidities_final_Not known         0
# Comorbidities_final_Other cancer      0
# ECOG_final_1                          0
# ECOG_final_2                          0
# ECOG_final_3                          0
# ECOG_final_4                          0
# ECOG_final_Not known                  0
# Gall_stone_final_Not known            0
# Gall_stone_final_Polyp                0
# Gall_stone_final_Yes                  0
# Tumour_stage_final_Stage II           0
# Tumour_stage_final_Stage III          0
# Tumour_stage_final_Stage IV           0
# Surgery_final_Partial                 0
# Surgery_final_Radical                 0
# Surgery_final_Simple                  0
# Treatment_final_Disease Control       0
# Treatment_final_Palliative_care       0
# GENDER_MALE                           0
# Diabetes_final_Not known              0
# Diabetes_final_Yes                    0
# Status                                0
# AGE                                   0
# HEIGHT                                0
# WEIGHT                                0
# BILIRUBIN CONJUGATED                  0
# BILIRUBIN UNCONJUGATED                0
# BILIRUBIN TOTAL                       0
# AST - SGOT                            0
# ALT - SGPT                            0
# ALK PHOS [ALP]                        0
# GAMMA GT                              0
# ALBUMIN                               0
# Time_overall_study                    0
# dtype: int64

# %%
from lifelines import CoxPHFitter 

cph = CoxPHFitter(alpha=0.05)
cph.fit(df, duration_col='Time_overall_study', 
              event_col='Status',
              show_progress = True)
# Out:
# Iteration 1: norm_delta = 1.20703, step_size = 0.9500, log_lik = -879.15677, newton_decrement = 55.18142, seconds_since_start = 0.1
# Iteration 2: norm_delta = 0.56367, step_size = 0.9500, log_lik = -864.41011, newton_decrement = 29.20152, seconds_since_start = 0.1
# Iteration 3: norm_delta = 0.10949, step_size = 0.9500, log_lik = -835.30056, newton_decrement = 1.05597, seconds_since_start = 0.1
# Iteration 4: norm_delta = 0.02177, step_size = 1.0000, log_lik = -834.13780, newton_decrement = 0.04178, seconds_since_start = 0.1
# Iteration 5: norm_delta = 0.00159, step_size = 1.0000, log_lik = -834.09433, newton_decrement = 0.00018, seconds_since_start = 0.1
# Iteration 6: norm_delta = 0.00001, step_size = 1.0000, log_lik = -834.09415, newton_decrement = 0.00000, seconds_since_start = 0.1
# Convergence success after 6 iterations.
# <lifelines.CoxPHFitter: fitted with 203 total observations, 0 right-censored observations>

# %%
cph.print_summary(decimals=3)
# Out:
# <lifelines.CoxPHFitter: fitted with 203 total observations, 0 right-censored observations>
#              duration col = 'Time_overall_study'
#                 event col = 'Status'
#       baseline estimation = breslow
#    number of observations = 203
# number of events observed = 203
#    partial log-likelihood = -834.094
#          time fit was run = 2023-10-09 10:15:23 UTC
#
# ---
#                                      coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# Comorbidities_final_Kidney disease -0.473      0.623      0.745           -1.933            0.986                0.145                2.681
# Comorbidities_final_Lungs disease   0.047      1.048      0.651           -1.228            1.323                0.293                3.754
# Comorbidities_final_No              0.228      1.256      0.366           -0.489            0.944                0.613                2.571
# Comorbidities_final_Not known       0.106      1.111      0.564           -0.999            1.210                0.368                3.355
# Comorbidities_final_Other cancer    0.765      2.148      0.732           -0.669            2.199                0.512                9.012
# ECOG_final_1                       -0.849      0.428      0.385           -1.603           -0.095                0.201                0.909
# ECOG_final_2                       -0.701      0.496      0.394           -1.474            0.072                0.229                1.074
# ECOG_final_3                       -0.340      0.711      0.564           -1.446            0.765                0.236                2.149
# ECOG_final_4                       -0.195      0.823      0.931           -2.021            1.631                0.133                5.107
# ECOG_final_Not known                0.121      1.129      0.810           -1.467            1.710                0.231                5.527
# Gall_stone_final_Not known          0.393      1.481      0.234           -0.067            0.852                0.936                2.345
# Gall_stone_final_Polyp             -1.362      0.256      1.151           -3.617            0.894                0.027                2.444
# Gall_stone_final_Yes                0.499      1.647      0.212            0.084            0.914                1.088                2.494
# Tumour_stage_final_Stage II        -0.138      0.871      0.565           -1.246            0.970                0.288                2.637
# Tumour_stage_final_Stage III       -0.178      0.837      0.421           -1.003            0.648                0.367                1.911
# Tumour_stage_final_Stage IV        -0.549      0.577      0.346           -1.228            0.129                0.293                1.138
# Surgery_final_Partial              -0.851      0.427      0.645           -2.116            0.413                0.121                1.512
# Surgery_final_Radical              -0.561      0.571      0.463           -1.468            0.346                0.230                1.414
# Surgery_final_Simple               -0.360      0.697      0.207           -0.766            0.045                0.465                1.046
# Treatment_final_Disease Control    -0.467      0.627      0.535           -1.515            0.582                0.220                1.789
# Treatment_final_Palliative_care     0.356      1.428      0.595           -0.810            1.523                0.445                4.586
# GENDER_MALE                         0.038      1.039      0.197           -0.348            0.424                0.706                1.528
# Diabetes_final_Not known            0.237      1.268      0.520           -0.782            1.257                0.458                3.513
# Diabetes_final_Yes                  0.211      1.235      0.193           -0.167            0.590                0.846                1.803
# AGE                                -0.003      0.997      0.009           -0.021            0.015                0.980                1.015
# HEIGHT                              0.003      1.003      0.003           -0.004            0.009                0.996                1.009
# WEIGHT                             -0.010      0.990      0.007           -0.025            0.004                0.975                1.004
# BILIRUBIN CONJUGATED                0.124      1.132      0.052            0.023            0.225                1.023                1.253
# BILIRUBIN UNCONJUGATED             -0.341      0.711      0.246           -0.824            0.142                0.439                1.153
# BILIRUBIN TOTAL                     0.010      1.010      0.028           -0.045            0.064                0.956                1.066
# AST - SGOT                          0.000      1.000      0.001           -0.001            0.001                0.999                1.001
# ALT - SGPT                         -0.001      0.999      0.001           -0.003            0.002                0.997                1.002
# ALK PHOS [ALP]                      0.000      1.000      0.000           -0.000            0.001                1.000                1.001
# GAMMA GT                            0.000      1.000      0.000           -0.000            0.001                1.000                1.001
# ALBUMIN                            -0.339      0.713      0.144           -0.621           -0.056                0.538                0.945
#
#                                      cmp to      z     p   -log2(p)
# covariate
# Comorbidities_final_Kidney disease    0.000 -0.636 0.525      0.930
# Comorbidities_final_Lungs disease     0.000  0.073 0.942      0.086
# Comorbidities_final_No                0.000  0.623 0.533      0.908
# Comorbidities_final_Not known         0.000  0.188 0.851      0.232
# Comorbidities_final_Other cancer      0.000  1.045 0.296      1.757
# ECOG_final_1                          0.000 -2.208 0.027      5.198
# ECOG_final_2                          0.000 -1.778 0.075      3.731
# ECOG_final_3                          0.000 -0.604 0.546      0.873
# ECOG_final_4                          0.000 -0.209 0.834      0.262
# ECOG_final_Not known                  0.000  0.150 0.881      0.183
# Gall_stone_final_Not known            0.000  1.676 0.094      3.416
# Gall_stone_final_Polyp                0.000 -1.183 0.237      2.079
# Gall_stone_final_Yes                  0.000  2.359 0.018      5.771
# Tumour_stage_final_Stage II           0.000 -0.244 0.807      0.310
# Tumour_stage_final_Stage III          0.000 -0.422 0.673      0.571
# Tumour_stage_final_Stage IV           0.000 -1.586 0.113      3.150
# Surgery_final_Partial                 0.000 -1.319 0.187      2.418
# Surgery_final_Radical                 0.000 -1.212 0.226      2.149
# Surgery_final_Simple                  0.000 -1.742 0.081      3.618
# Treatment_final_Disease Control       0.000 -0.873 0.383      1.385
# Treatment_final_Palliative_care       0.000  0.599 0.549      0.864
# GENDER_MALE                           0.000  0.193 0.847      0.239
# Diabetes_final_Not known              0.000  0.457 0.648      0.626
# Diabetes_final_Yes                    0.000  1.096 0.273      1.872
# AGE                                   0.000 -0.308 0.758      0.400
# HEIGHT                                0.000  0.852 0.394      1.342
# WEIGHT                                0.000 -1.383 0.167      2.585
# BILIRUBIN CONJUGATED                  0.000  2.410 0.016      5.972
# BILIRUBIN UNCONJUGATED                0.000 -1.384 0.166      2.587
# BILIRUBIN TOTAL                       0.000  0.350 0.726      0.461
# AST - SGOT                            0.000  0.601 0.548      0.868
# ALT - SGPT                            0.000 -0.500 0.617      0.697
# ALK PHOS [ALP]                        0.000  1.332 0.183      2.452
# GAMMA GT                              0.000  0.956 0.339      1.560
# ALBUMIN                               0.000 -2.351 0.019      5.741
# ---
# Concordance = 0.685
# Partial AIC = 1738.188
# log-likelihood ratio test = 90.125 on 35 df
# -log2(p) of ll-ratio test = 20.015

# %% [markdown]
# ## Feature Importance #

# %% [markdown]
# ### Using Cox PH Model ###

# %%
########### FEATURE IMPORTANCE ##############

# %%
import numpy as np
import pandas as pd
from lifelines import CoxPHFitter
import matplotlib.pyplot as plt

# Load your cancer patient data into a pandas DataFrame with 'time' and 'event' columns
# Replace 'data' with your own dataset
data = df.copy()

# Create a Cox Proportional Hazard model
cph = CoxPHFitter()
cph.fit(data, duration_col='Time_overall_study', event_col='Status')

# Display feature importance
cph.print_summary()
# Out:
# <lifelines.CoxPHFitter: fitted with 203 total observations, 0 right-censored observations>
#              duration col = 'Time_overall_study'
#                 event col = 'Status'
#       baseline estimation = breslow
#    number of observations = 203
# number of events observed = 203
#    partial log-likelihood = -834.09
#          time fit was run = 2023-10-09 10:15:24 UTC
#
# ---
#                                      coef  exp(coef)   se(coef)   coef lower 95%   coef upper 95%  exp(coef) lower 95%  exp(coef) upper 95%
# covariate
# Comorbidities_final_Kidney disease  -0.47       0.62       0.74            -1.93             0.99                 0.14                 2.68
# Comorbidities_final_Lungs disease    0.05       1.05       0.65            -1.23             1.32                 0.29                 3.75
# Comorbidities_final_No               0.23       1.26       0.37            -0.49             0.94                 0.61                 2.57
# Comorbidities_final_Not known        0.11       1.11       0.56            -1.00             1.21                 0.37                 3.35
# Comorbidities_final_Other cancer     0.76       2.15       0.73            -0.67             2.20                 0.51                 9.01
# ECOG_final_1                        -0.85       0.43       0.38            -1.60            -0.10                 0.20                 0.91
# ECOG_final_2                        -0.70       0.50       0.39            -1.47             0.07                 0.23                 1.07
# ECOG_final_3                        -0.34       0.71       0.56            -1.45             0.77                 0.24                 2.15
# ECOG_final_4                        -0.20       0.82       0.93            -2.02             1.63                 0.13                 5.11
# ECOG_final_Not known                 0.12       1.13       0.81            -1.47             1.71                 0.23                 5.53
# Gall_stone_final_Not known           0.39       1.48       0.23            -0.07             0.85                 0.94                 2.34
# Gall_stone_final_Polyp              -1.36       0.26       1.15            -3.62             0.89                 0.03                 2.44
# Gall_stone_final_Yes                 0.50       1.65       0.21             0.08             0.91                 1.09                 2.49
# Tumour_stage_final_Stage II         -0.14       0.87       0.57            -1.25             0.97                 0.29                 2.64
# Tumour_stage_final_Stage III        -0.18       0.84       0.42            -1.00             0.65                 0.37                 1.91
# Tumour_stage_final_Stage IV         -0.55       0.58       0.35            -1.23             0.13                 0.29                 1.14
# Surgery_final_Partial               -0.85       0.43       0.65            -2.12             0.41                 0.12                 1.51
# Surgery_final_Radical               -0.56       0.57       0.46            -1.47             0.35                 0.23                 1.41
# Surgery_final_Simple                -0.36       0.70       0.21            -0.77             0.05                 0.47                 1.05
# Treatment_final_Disease Control     -0.47       0.63       0.53            -1.52             0.58                 0.22                 1.79
# Treatment_final_Palliative_care      0.36       1.43       0.60            -0.81             1.52                 0.44                 4.59
# GENDER_MALE                          0.04       1.04       0.20            -0.35             0.42                 0.71                 1.53
# Diabetes_final_Not known             0.24       1.27       0.52            -0.78             1.26                 0.46                 3.51
# Diabetes_final_Yes                   0.21       1.24       0.19            -0.17             0.59                 0.85                 1.80
# AGE                                 -0.00       1.00       0.01            -0.02             0.02                 0.98                 1.02
# HEIGHT                               0.00       1.00       0.00            -0.00             0.01                 1.00                 1.01
# WEIGHT                              -0.01       0.99       0.01            -0.02             0.00                 0.98                 1.00
# BILIRUBIN CONJUGATED                 0.12       1.13       0.05             0.02             0.23                 1.02                 1.25
# BILIRUBIN UNCONJUGATED              -0.34       0.71       0.25            -0.82             0.14                 0.44                 1.15
# BILIRUBIN TOTAL                      0.01       1.01       0.03            -0.04             0.06                 0.96                 1.07
# AST - SGOT                           0.00       1.00       0.00            -0.00             0.00                 1.00                 1.00
# ALT - SGPT                          -0.00       1.00       0.00            -0.00             0.00                 1.00                 1.00
# ALK PHOS [ALP]                       0.00       1.00       0.00            -0.00             0.00                 1.00                 1.00
# GAMMA GT                             0.00       1.00       0.00            -0.00             0.00                 1.00                 1.00
# ALBUMIN                             -0.34       0.71       0.14            -0.62            -0.06                 0.54                 0.95
#
#                                      cmp to     z    p   -log2(p)
# covariate
# Comorbidities_final_Kidney disease     0.00 -0.64 0.53       0.93
# Comorbidities_final_Lungs disease      0.00  0.07 0.94       0.09
# Comorbidities_final_No                 0.00  0.62 0.53       0.91
# Comorbidities_final_Not known          0.00  0.19 0.85       0.23
# Comorbidities_final_Other cancer       0.00  1.05 0.30       1.76
# ECOG_final_1                           0.00 -2.21 0.03       5.20
# ECOG_final_2                           0.00 -1.78 0.08       3.73
# ECOG_final_3                           0.00 -0.60 0.55       0.87
# ECOG_final_4                           0.00 -0.21 0.83       0.26
# ECOG_final_Not known                   0.00  0.15 0.88       0.18
# Gall_stone_final_Not known             0.00  1.68 0.09       3.42
# Gall_stone_final_Polyp                 0.00 -1.18 0.24       2.08
# Gall_stone_final_Yes                   0.00  2.36 0.02       5.77
# Tumour_stage_final_Stage II            0.00 -0.24 0.81       0.31
# Tumour_stage_final_Stage III           0.00 -0.42 0.67       0.57
# Tumour_stage_final_Stage IV            0.00 -1.59 0.11       3.15
# Surgery_final_Partial                  0.00 -1.32 0.19       2.42
# Surgery_final_Radical                  0.00 -1.21 0.23       2.15
# Surgery_final_Simple                   0.00 -1.74 0.08       3.62
# Treatment_final_Disease Control        0.00 -0.87 0.38       1.39
# Treatment_final_Palliative_care        0.00  0.60 0.55       0.86
# GENDER_MALE                            0.00  0.19 0.85       0.24
# Diabetes_final_Not known               0.00  0.46 0.65       0.63
# Diabetes_final_Yes                     0.00  1.10 0.27       1.87
# AGE                                    0.00 -0.31 0.76       0.40
# HEIGHT                                 0.00  0.85 0.39       1.34
# WEIGHT                                 0.00 -1.38 0.17       2.58
# BILIRUBIN CONJUGATED                   0.00  2.41 0.02       5.97
# BILIRUBIN UNCONJUGATED                 0.00 -1.38 0.17       2.59
# BILIRUBIN TOTAL                        0.00  0.35 0.73       0.46
# AST - SGOT                             0.00  0.60 0.55       0.87
# ALT - SGPT                             0.00 -0.50 0.62       0.70
# ALK PHOS [ALP]                         0.00  1.33 0.18       2.45
# GAMMA GT                               0.00  0.96 0.34       1.56
# ALBUMIN                                0.00 -2.35 0.02       5.74
# ---
# Concordance = 0.69
# Partial AIC = 1738.19
# log-likelihood ratio test = 90.13 on 35 df
# -log2(p) of ll-ratio test = 20.01

# %% [markdown]
# #####################################################################
# ### FEATURE IMPORTANCE BASED ON THE COEFFICIENTS OF COX-PH MODEL

# %%
import pandas as pd
import numpy as np
from lifelines import CoxPHFitter
import matplotlib.pyplot as plt

# %%
data = df.copy()

from lifelines.utils import survival_table_from_events

time_column = 'Time_overall_study'  
event_column = 'Status'  

cph = CoxPHFitter()
cph.fit(data, duration_col=time_column, event_col=event_column)
# Out:
# <lifelines.CoxPHFitter: fitted with 203 total observations, 0 right-censored observations>

# %%
feature_importance = pd.DataFrame({'Feature': data.drop([time_column, event_column], axis=1).columns,
                                   'Coefficient': cph.summary['coef'].values})
feature_importance['Abs_Coefficient'] = np.abs(feature_importance['Coefficient'])

# %%
feature_importance = feature_importance.sort_values(by='Coefficient', ascending=False)

# Plot the feature importance
plt.figure(figsize=(10, 6))
plt.barh(feature_importance['Feature'], feature_importance['Coefficient'], color='skyblue')
plt.xlabel('Coefficient')
plt.ylabel('Feature')
plt.title('Feature Importance in Cox Survival Model')
plt.gca().invert_yaxis()  # Reverse the order to have the most important feature at the top
plt.show()

# %%
# Calculate the absolute values of coefficients and sort in descending order
feature_importance_sorted = feature_importance.copy()
feature_importance_sorted['Abs_Coefficient'] = abs(feature_importance_sorted['Coefficient'])
feature_importance_sorted = feature_importance_sorted.sort_values(by='Abs_Coefficient', ascending=False)

# Extract the top 7 features with the highest absolute coefficients
top_features = feature_importance_sorted['Feature'].head(7)

# Filter the feature_importance DataFrame to keep only the top features
top_feature_importance = feature_importance_sorted[feature_importance_sorted['Feature'].isin(top_features)]

# Plot the feature importance of the top 7 features based on magnitude
plt.figure(figsize=(10, 6))
plt.barh(top_feature_importance['Feature'], top_feature_importance['Coefficient'], color='skyblue')
plt.xlabel('Coefficient (Magnitude)')
plt.ylabel('Feature')
plt.title('Top 7 Features with Highest Absolute Coefficients (Magnitude)')
plt.gca().invert_yaxis()  # Reverse the order to have the most important feature at the top
plt.show()

# %% [markdown]
# ### HAZARD RATIOS PLOT BASED ON COX-PH MODEL

# %%
import pandas as pd
import numpy as np
from lifelines import CoxPHFitter
import matplotlib.pyplot as plt

time_column = 'Time_overall_study'  
event_column = 'Status'  

cph = CoxPHFitter()
cph.fit(data, duration_col=time_column, event_col=event_column)

# Calculate hazard ratios and standard errors
hazard_ratios = np.exp(cph.summary['coef'])
standard_errors = cph.summary['se(coef)']

# Calculate confidence intervals
ci_lower = hazard_ratios * np.exp(-1.96 * standard_errors)
ci_upper = hazard_ratios * np.exp(1.96 * standard_errors)
features = cph.summary.index

# Create a dataframe to store the results
hr_df = pd.DataFrame({'Features': features, 'Hazard Ratio': hazard_ratios, 'CI Lower': ci_lower, 'CI Upper': ci_upper})

# Sort the features by their hazard ratios
hr_df = hr_df.sort_values(by='Hazard Ratio', ascending=False)

# Plot the hazard ratios with confidence intervals
plt.figure(figsize=(10, 6))
plt.errorbar(hr_df['Hazard Ratio'], hr_df['Features'], xerr=[hr_df['Hazard Ratio'] - hr_df['CI Lower'], hr_df['CI Upper'] - hr_df['Hazard Ratio']], fmt='o', color='skyblue')
plt.xscale('log')  # Use a log scale for better visualization
plt.xlabel('Hazard Ratio (log scale)')
plt.ylabel('Features')
plt.title('Hazard Ratios for Cox Survival Model')
plt.gca().invert_yaxis()  # Reverse the order to have the highest hazard ratio at the top
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %%
import shap
import numpy as np

# Fit a Cox PH model
cph = CoxPHFitter()
cph.fit(df, duration_col='Time_overall_study', event_col='Status')

# Define a function that takes feature values as input and returns the negative of the partial hazard
def predict_survival(input_features):
    # Create a DataFrame with the input features and provide column names
    input_df = pd.DataFrame(input_features, columns=df.drop(['Time_overall_study', 'Status'], axis=1).columns)
    return -cph.predict_partial_hazard(input_df)

# Create a SHAP explainer for survival analysis
explainer = shap.Explainer(predict_survival, df.drop(['Time_overall_study', 'Status'], axis=1).values)
shapley_values = explainer.shap_values(df.drop(['Time_overall_study', 'Status'], axis=1).values)

# Visualize feature importances using SHAP values
shap.summary_plot(shapley_values, df.drop(['Time_overall_study', 'Status'], axis=1), show=False)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
# Calculate the mean SHAP value for each feature (average impact)
mean_shapley_values = shapley_values.mean(axis=0)

# Get the indices of the top 7 features with the highest mean SHAP values
top_feature_indices = np.argsort(mean_shapley_values)[-7:]

# Get the corresponding feature names
top_feature_names = df.drop(['Time_overall_study', 'Status'], axis=1).columns[top_feature_indices]

# Plot the top 7 features
plt.figure(figsize=(10, 6))
plt.barh(range(len(top_feature_indices)), mean_shapley_values[top_feature_indices], align='center')
plt.yticks(range(len(top_feature_indices)), top_feature_names)
plt.xlabel('Mean SHAP Value')
plt.title('Top 7 Features with Highest Mean SHAP Values')
plt.gca().invert_yaxis()  # Invert the y-axis to show the most significant feature at the top
plt.show()

# %%
# Calculate the absolute SHAP values for each feature
abs_shapley_values = np.abs(shapley_values)

# Calculate the mean absolute SHAP value for each feature (average impact)
mean_abs_shapley_values = abs_shapley_values.mean(axis=0)

# Get the indices of the top 7 features with the highest mean absolute SHAP values
top_feature_indices = np.argsort(mean_abs_shapley_values)[-7:]

# Get the corresponding feature names
top_feature_names = df.drop(['Time_overall_study', 'Status'], axis=1).columns[top_feature_indices]

# Plot the top 7 features
plt.figure(figsize=(10, 6))
plt.barh(range(len(top_feature_indices)), mean_abs_shapley_values[top_feature_indices], align='center')
plt.yticks(range(len(top_feature_indices)), top_feature_names)
plt.xlabel('Mean Absolute SHAP Value')
plt.title('Top 7 Features with Highest Mean Absolute SHAP Values')
plt.gca().invert_yaxis()  # Invert the y-axis to show the most significant feature at the top
plt.show()

# %%
###### RANDOM SURVIVAL FOREST ######

# %%
df["Status"].value_counts()
# Out:
# 1    203
# Name: Status, dtype: int64

# %%
data['Status'].dtype
# Out:
# dtype('int64')

# %%
##BASED ON PERMUTATION IMPORTANCE

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sksurv.ensemble import RandomSurvivalForest
from sksurv.preprocessing import OneHotEncoder
from sksurv.metrics import concordance_index_censored
from sksurv.util import Surv
from sklearn.inspection import permutation_importance

data = df.copy()

# Define the target variables (survival time and event indicator)
survival_data = np.array(list(zip(data['Status'], data['Time_overall_study'])), dtype=[('Status', bool), ('Time_overall_study', float)])

# Drop the target variables from the features
X = data.drop(['Time_overall_study', 'Status'], axis=1)

# Split the dataset into training and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, survival_data, test_size=0.2, random_state=24)

# Fit a Random Survival Forest model
rsf = RandomSurvivalForest(n_estimators=100, random_state=24)
rsf.fit(X_train, y_train)

# Calculate the concordance index (C-index) on the test set
c_index = concordance_index_censored(y_test['Status'], y_test['Time_overall_study'], rsf.predict(X_test))
print(f'Concordance Index (C-index): {c_index[0]:.4f}')

# Calculate feature importances using permutation importance
result = permutation_importance(rsf, X_test, y_test, n_repeats=30, random_state=24)
importances = result.importances_mean
feature_names = X_test.columns

# Calculate the total importance sum for scaling to percentage
total_importance = importances.sum()

# Normalize importances to percentage
importances_percentage = (importances / total_importance) * 100

# Print the values of importance for each feature
for feature, importance in zip(feature_names, importances_percentage):
    print(f'{feature}: {importance:.2f}%')

# Sort features by importance
sorted_idx = np.argsort(importances_percentage)[::-1]

# Plot the top N important features with y-axis inverted
top_n = 7  # Change this to the number of top features you want to plot
plt.figure(figsize=(10, 6))
plt.barh(range(top_n), importances_percentage[sorted_idx][:top_n], align="center")
plt.yticks(range(top_n), feature_names[sorted_idx][:top_n])
plt.xlabel("Importance (%)")
plt.ylabel("Feature")
plt.title("Feature Importance (Permutation Importance)")
plt.gca().invert_yaxis()  # Reverse the y-axis
plt.show()
# Out:
# Concordance Index (C-index): 0.7204
# Comorbidities_final_Kidney disease: 0.00%
# Comorbidities_final_Lungs disease: 0.00%
# Comorbidities_final_No: 2.72%
# Comorbidities_final_Not known: 0.61%
# Comorbidities_final_Other cancer: 0.00%
# ECOG_final_1: 0.14%
# ECOG_final_2: -0.75%
# ECOG_final_3: 1.19%
# ECOG_final_4: 0.00%
# ECOG_final_Not known: 0.00%
# Gall_stone_final_Not known: 1.17%
# Gall_stone_final_Polyp: 0.00%
# Gall_stone_final_Yes: 1.80%
# Tumour_stage_final_Stage II: 0.00%
# Tumour_stage_final_Stage III: -0.50%
# Tumour_stage_final_Stage IV: -0.22%
# Surgery_final_Partial: 0.00%
# Surgery_final_Radical: 3.97%
# Surgery_final_Simple: 4.97%
# Treatment_final_Disease Control: 11.05%
# Treatment_final_Palliative_care: 26.01%
# GENDER_MALE: -1.97%
# Diabetes_final_Not known: 0.58%
# Diabetes_final_Yes: 2.08%
# AGE: 4.86%
# HEIGHT: -2.19%
# WEIGHT: -0.19%
# BILIRUBIN CONJUGATED: 1.78%
# BILIRUBIN UNCONJUGATED: 2.53%
# BILIRUBIN TOTAL: 0.44%
# AST - SGOT: 8.66%
# ALT - SGPT: 2.22%
# ALK PHOS [ALP]: 2.55%
# GAMMA GT: 8.52%
# ALBUMIN: 17.99%

# %%
## MUTUAL INFORMATION

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_selection import mutual_info_regression
from sksurv.ensemble import RandomSurvivalForest
from sksurv.metrics import concordance_index_censored

# Load your survival dataset or create one (replace with your data)
# Ensure your dataset contains columns 'Status' for event indicator and 'Time_overall_study' for survival time

# Define your dataset here (replace this)
data = df.copy()

# Define the target variables (survival time and event indicator)
survival_data = data[['Status', 'Time_overall_study']].to_records(index=False)

# Drop the target variables from the features
X = data.drop(['Time_overall_study', 'Status'], axis=1)

# Calculate mutual information between features and survival time
mutual_info = mutual_info_regression(X, data['Time_overall_study'])

# Create a DataFrame to store feature names and their corresponding importances
importance_df = pd.DataFrame({'Feature': X.columns, 'Importance': mutual_info})

# Sort the DataFrame by importance in descending order
importance_df = importance_df.sort_values(by='Importance', ascending=False)

# Plot the top N features with horizontal bar plot
top_n = 10  # Change this to the number of top features you want to plot
plt.figure(figsize=(10, 6))
plt.barh(range(top_n), importance_df['Importance'][:top_n], align='center')
plt.yticks(range(top_n), importance_df['Feature'][:top_n])
plt.xlabel('Importance (Mutual Information)')
plt.title('Top Features by Mutual Information Importance - "Mutual information (variable) w.r.t \nStatus (target)"')
plt.gca().invert_yaxis()  # Invert the y-axis to show the most significant feature at the top
plt.show()

# %%
##########################################################################################
